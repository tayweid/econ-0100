# %%
from Video import *
warnings.filterwarnings('ignore')

""" Paths """
tutorial_path = 'PartA_E2'
if not os.path.exists(tutorial_path):
    os.makedirs(tutorial_path)
config.media_dir = tutorial_path
config.verbosity = 'ERROR'

""" Colors """
CUSTOM_BLACK = '#1f1f1f'
CUSTOM_GREY = '#696969'
DEFINITION = '#FFD700'
config.background_color = CUSTOM_BLACK
config.axes_color = CUSTOM_GREY

""" Frames """
PIXEL_HEIGHT = 1080
FPS = 10
config.pixel_height = PIXEL_HEIGHT
config.pixel_width = PIXEL_HEIGHT*2
config.frame_rate = FPS

# %% [markdown]
# # More can be possible! | Part A | Episode 2

# %% [markdown]
# ## Animation 0 | Intro Sequence

# %%
# %%manim animation_0
#
# class animation_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part A}} $|$ Episode 2').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part A": BLUE,}
#         ).scale(3).move_to(DOWN)
#         self.play(AddTextWordByWord(part_label), Squares.animate.to_edge(UP, buff=1))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         self.wait()
# Out:
# Manim Community v0.18.1

# %% [markdown]
# ## Animation 1 | Last Time...

# %%
# %%manim animation_1
#
# class animation_1(Scene):
#
#     def construct(self):
#         text = Tex('Last Time...').scale(3)
#         self.play(FadeIn(text), run_time=1/2)
#         self.wait()
#         self.play(FadeOut(text), run_time=1/2)
#         self.wait()
# Out:
# Manim Community v0.18.1
# <video src="PartA_E2/jupyter/animation_1@2024-08-27@23-13-51.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Animation 2 | Make the Op Cost Table

# %%
# %%manim animation_2
#
# class animation_2(MovingCameraScene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         PPF_axis = Axes(
#             x_range=[0, 65, 5],
#             x_length = 7,
#             axis_config={"color": WHITE},
#             x_axis_config={
#                 "numbers_to_include": np.arange(0, 65, 15),
#                 "numbers_with_elongated_ticks": np.arange(0, 65, 10),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":GREEN,
#                 },
#             },
#             y_range=[0, 10, 1],
#             y_length = 6,
#             y_axis_config={
#                 "numbers_to_include": np.arange(0, 11, 2),
#                 "numbers_with_elongated_ticks": np.arange(0, 11, 5),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":ORANGE,
#                 }
#             },
#             tips=False,
#         )
#
#         """ Starting Objects """
#
#         axes = PPF_axis.shift(RIGHT*2).scale(0.8)
#
#         ppf_molly_graph = axes.plot(PPF_Molly, color=BLUE, x_range=(0, 45))
#         molly = Rectangle(height=3, width=3, color=BLUE).move_to(LEFT*4.5 + UP*2)
#         molly.z_index = 2
#         molly_name = Tex("Molly").scale(1.5).next_to(molly,LEFT,buff=-1/2).set_color(BLUE).rotate(np.pi/2)
#         molly_group = VGroup(molly,molly_name)
#
#         m_carrots = Rectangle(height=3/2, width=3, color=ORANGE, fill_opacity=1)
#         m_spinach = Rectangle(height=3/2, width=3, color=GREEN, fill_opacity=1)
#         molly_crops = VGroup(m_carrots,m_spinach.next_to(m_carrots,DOWN,buff=0)).move_to(molly)
#
#         ppf_andrew_graph = axes.plot(PPF_Andrew, color=RED, x_range=(0, 18))
#         andrew = Rectangle(height=3, width=3, color=RED).move_to(LEFT*4.5 + DOWN*2)
#         andrew.z_index = 2
#         andrew_name = Tex("Andrew").scale(1.5).next_to(andrew,LEFT,buff=-0.8).set_color(RED).rotate(np.pi/2)
#         andrew_group = VGroup(andrew,andrew_name)
#
#         a_carrots = Rectangle(height=3/2, width=3, color=ORANGE, fill_opacity=1)
#         a_spinach = Rectangle(height=3/2, width=3, color=GREEN, fill_opacity=1)
#         andrew_crops = VGroup(a_carrots,a_spinach.next_to(a_carrots,DOWN,buff=0)).move_to(andrew)
#
#         """ Setup """
#
#         self.play(FadeIn(molly_group),FadeIn(andrew_group))
#         self.wait()
#
#         """ Production Table """
#
#         production_table = Table(
#             [["5", "45"],
#             ["4", "18"]],
#             row_labels=[Text("Molly").set_color(BLUE), Text("Andrew").set_color(RED)],
#             col_labels=[Text("Carrots").set_color(ORANGE), Text("Spinach").set_color(GREEN)]
#         ).scale(0.8)
#         production_table_definition = Tex("{{Production Table}}: Farmers' Capacities"
#                                          ).set_color_by_tex_to_color_map(
#             { "Production Table": DEFINITION}
#         ).next_to(production_table, UP, buff=1)
#         production_table_group = VGroup(production_table, production_table_definition).to_edge(RIGHT, buff=1)
#         self.play(FadeIn(production_table_group))
#         self.wait()
#
#         """ Opportunity Cost Table """
#
#         cost_table = Table(
#             [["9 S", "1/9 C"],
#             ["9/2 S", "2/9 C"]],
#             row_labels=[Text("Molly").set_color(BLUE), Text("Andrew").set_color(RED)],
#             col_labels=[Text("Carrots").set_color(ORANGE), Text("Spinach").set_color(GREEN)]
#         ).scale(0.8)
#         for e in [3,4,6,7]:
#             cost_table.get_elements()[e].set_color(CUSTOM_BLACK)
#         cost_table_definition = Tex("{{Op. Cost Table}}: Farmers' Costs"
#                                          ).set_color_by_tex_to_color_map(
#             { "Op. Cost Table": DEFINITION}
#         ).next_to(cost_table, UP, buff=1)
#         cost_table_group = VGroup(cost_table, cost_table_definition).next_to(production_table_group, RIGHT, buff=1)
#
#         table_group = VGroup(production_table_group, cost_table_group)
#         self.play(
#             self.camera.frame.animate.move_to(table_group).set(width=table_group.width*1.1).shift(DOWN),
#             FadeIn(cost_table_group),
#             FadeOut(molly_group),
#             FadeOut(andrew_group),
#         )
#         self.wait()
#
#         """ Some Math | Molly """
#
#         box = SurroundingRectangle(production_table.get_rows()[1], buff=1/2)
#         self.play(FadeIn(box))
#         self.wait()
#
#         equal = Tex("=").next_to(table_group, DOWN, buff=2).scale(1.5)
#         carrot_harvest = Tex('{{5}} {{C}}').scale(1.5).next_to(equal, LEFT, buff=1).set_color_by_tex_to_color_map({
#                 "C": ORANGE,
#             })
#         spinach_harvest = Tex('{{45}} {{S}}').scale(1.5).next_to(equal, RIGHT, buff=1).set_color_by_tex_to_color_map({
#                 "S": GREEN,
#             })
#         math_group = VGroup(carrot_harvest, equal, spinach_harvest)
#         hidden_math_text = Tex("Hidden math text temp fix").move_to(math_group) # surrounding rectangle is being bad
#         new_box = SurroundingRectangle(hidden_math_text, buff=1/2)
#         self.play(Transform(box, new_box), FadeIn(equal),FadeIn(carrot_harvest), FadeIn(spinach_harvest))
#         self.wait(1/2)
#
#         spinach_harvest_new = Tex(r"{{$\frac{45}{5}$}} {{S}}").scale(1.5).next_to(equal,RIGHT,buff=1).set_color_by_tex_to_color_map({
#                 "S": GREEN,
#             })
#         carrot_harvest_new = Tex(r"$\frac{5}{5}$ {{C}}").scale(1.5).next_to(equal,LEFT,buff=1).set_color_by_tex_to_color_map({
#                 "C": ORANGE,
#             })
#         self.play(Transform(carrot_harvest[0],carrot_harvest_new[0]),Transform(spinach_harvest[0],spinach_harvest_new[0]))
#         self.wait(1/2)
#
#         spinach_harvest_new = Tex('{{9}} {{S}}').scale(1.5).next_to(equal,RIGHT,buff=1).set_color_by_tex_to_color_map({
#                 "S": GREEN,
#             })
#         carrot_harvest_new = Tex('{{1}} {{C}}').scale(1.5).next_to(equal,LEFT,buff=1).set_color_by_tex_to_color_map({
#                 "C": ORANGE,
#             })
#         self.play(Transform(carrot_harvest[0],carrot_harvest_new[0]),Transform(spinach_harvest[0],spinach_harvest_new[0]))
#         self.wait(1/2)
#
#         op_cost = Tex("Opportunity Cost(1 {{$C$}}) = 9 {{$S$}}").scale(1.5).next_to(equal,UP,buff=2).set_color_by_tex_to_color_map({
#                 "$C$": ORANGE,
#                 "$S$": GREEN,
#             })
#         new_box = SurroundingRectangle(cost_table.get_elements()[3], buff=1/2)
#         self.play(Transform(box, new_box), cost_table.get_elements()[3].animate.set_color(GREEN))
#         self.wait()
#
#         new_box = SurroundingRectangle(hidden_math_text, buff=1/2)
#         self.play(Transform(box, new_box))
#         self.wait()
#
#         spinach_harvest_new = Tex('{{1}} {{S}}').scale(1.5).next_to(equal,RIGHT,buff=1).set_color_by_tex_to_color_map({
#                 "S": GREEN,
#             })
#         carrot_harvest_new = Tex(r"$\frac{1}{9}$}} {{C}}").scale(1.5).next_to(equal,LEFT,buff=1).set_color_by_tex_to_color_map({
#                 "C": ORANGE,
#             })
#         self.play(Transform(carrot_harvest[0],carrot_harvest_new[0]),Transform(spinach_harvest[0],spinach_harvest_new[0]))
#         self.wait(1/2)
#
#         new_box = SurroundingRectangle(cost_table.get_elements()[4], buff=1/2)
#         self.play(Transform(box, new_box),
#                   cost_table.get_elements()[4].animate.set_color(ORANGE),
#                   FadeOut(math_group),
#                   self.camera.frame.animate.shift(UP),
#                  )
#         self.wait()
#
#         """ Some Math | Andrew """
#
#         new_box = SurroundingRectangle(production_table.get_rows()[2], buff=1/2)
#         self.play(Transform(box, new_box))
#         self.wait()
#
#         new_box = SurroundingRectangle(cost_table.get_elements()[6:], buff=1/2)
#         self.play(Transform(box, new_box), cost_table.get_elements()[6].animate.set_color(GREEN), cost_table.get_elements()[7].animate.set_color(ORANGE))
#         self.play(FadeOut(box))
#         self.wait()
#
#         self.play(FadeOut(production_table_group), FadeOut(cost_table_group))
# Out:
# Manim Community v0.18.1
# <video src="PartA_E2/jupyter/animation_2@2024-08-27@23-30-10.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Animation 3 | Absolute and Comarative Advantage

# %%
# %%manim animation_3
#
# class animation_3(MovingCameraScene):
#
#     def construct(self):
#
#         """ Production Table """
#
#         production_table = Table(
#             [["5", "45"],
#             ["4", "18"]],
#             row_labels=[Text("Molly").set_color(BLUE), Text("Andrew").set_color(RED)],
#             col_labels=[Text("Carrots").set_color(ORANGE), Text("Spinach").set_color(GREEN)]
#         ).scale(0.8)
#         production_table_definition = Tex("{{Production Table}}: Farmers' Capacities"
#                                          ).set_color_by_tex_to_color_map(
#             { "Production Table": DEFINITION}
#         ).next_to(production_table, UP, buff=1)
#         production_table_group = VGroup(production_table, production_table_definition).to_edge(RIGHT, buff=1)
#
#         """ Opportunity Cost Table """
#
#         cost_table = Table(
#             [["9 S", "1/9 C"],
#             ["9/2 S", "2/9 C"]],
#             row_labels=[Text("Molly").set_color(BLUE), Text("Andrew").set_color(RED)],
#             col_labels=[Text("Carrots").set_color(ORANGE), Text("Spinach").set_color(GREEN)]
#         ).scale(0.8)
#         for e in [3,4,6,7]:
#             cost_table.get_elements()[e].set_color(CUSTOM_BLACK)
#         cost_table_definition = Tex("{{Op. Cost Table}}: Farmers' Costs"
#                                          ).set_color_by_tex_to_color_map(
#             { "Op. Cost Table": DEFINITION}
#         ).next_to(cost_table, UP, buff=1)
#         cost_table.get_elements()[3].set_color(GREEN)
#         cost_table.get_elements()[4].set_color(ORANGE)
#         cost_table.get_elements()[6].set_color(GREEN)
#         cost_table.get_elements()[7].set_color(ORANGE)
#
#         cost_table_group = VGroup(cost_table, cost_table_definition).next_to(production_table_group, RIGHT, buff=1)
#
#         table_group = VGroup(production_table_group, cost_table_group).scale(0.75).move_to(0).shift(UP)
#
#         #, self.camera.frame.animate.move_to(table_group).set(width=table_group.width*1.1).shift(DOWN)
#
#         """ Absolute Advantage """
#
#         definition = Tex("{{Absolute Advantage}} is having a higher productive capacity.").set_color_by_tex_to_color_map({
#             "Absolute Advantage": DEFINITION
#         })
#         self.play(AddTextWordByWord(definition))
#         self.wait()
#         self.play(FadeOut(definition))
#         self.play(FadeIn(table_group))
#
#         absolute_advantage = Tex("Absolute Advantage").set_color(DEFINITION).next_to(production_table, DOWN, buff=1)
#         self.play(FadeIn(absolute_advantage))
#         self.wait()
#
#         carrot_box_aa = SurroundingRectangle(production_table.get_elements()[3], buff=1/2)
#         self.play(FadeIn(carrot_box_aa))
#         self.wait()
#
#         spinach_box_aa = SurroundingRectangle(production_table.get_elements()[4], buff=1/2)
#         self.play(FadeIn(spinach_box_aa))
#         self.wait()
#
#         self.play(FadeOut(table_group), FadeOut(absolute_advantage), FadeOut(spinach_box_aa), FadeOut(carrot_box_aa))
#
#         """ Comparative Advantage Definition """
#
#         definition = Tex("{{Comparative Advantage}} is having a lower opportunity cost.").set_color_by_tex_to_color_map({
#             "Comparative Advantage": DEFINITION
#         })
#         self.play(AddTextWordByWord(definition))
#         self.wait()
#         self.play(FadeOut(definition))
#         self.play(FadeIn(table_group), FadeIn(absolute_advantage), FadeIn(spinach_box_aa), FadeIn(carrot_box_aa))
#
#         comparative_advantage = Tex("Comparative Advantage").set_color(DEFINITION).next_to(cost_table, DOWN, buff=1)
#         self.play(FadeIn(comparative_advantage))
#         self.wait()
#
#         spinach_box_ca = SurroundingRectangle(cost_table.get_elements()[6], buff=1/2)
#         self.play(FadeIn(spinach_box_ca))
#         self.wait()
#
#         carrot_box_ca = SurroundingRectangle(cost_table.get_elements()[4], buff=1/2)
#         self.play(FadeIn(carrot_box_ca))
#         self.wait()
#
#         self.play(FadeOut(table_group),
#                   FadeOut(absolute_advantage), FadeOut(spinach_box_aa), FadeOut(carrot_box_aa),
#                   FadeOut(comparative_advantage), FadeOut(spinach_box_ca), FadeOut(carrot_box_ca),
#                  )
# Out:
# Manim Community v0.18.1
# <video src="PartA_E2/jupyter/animation_3@2024-08-27@23-14-24.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Animation 4 | Introduce the Guild

# %%
# %%manim animation_4
#
# class animation_4(MovingCameraScene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         PPF_axis = Axes(
#             x_range=[0, 65, 5],
#             x_length = 7,
#             axis_config={"color": WHITE},
#             x_axis_config={
#                 "numbers_to_include": np.arange(0, 65, 15),
#                 "numbers_with_elongated_ticks": np.arange(0, 65, 10),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":GREEN,
#                 },
#             },
#             y_range=[0, 10, 1],
#             y_length = 6,
#             y_axis_config={
#                 "numbers_to_include": np.arange(0, 11, 2),
#                 "numbers_with_elongated_ticks": np.arange(0, 11, 5),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":ORANGE,
#                 }
#             },
#             tips=False,
#         )
#
#         """ Starting Objects """
#
#         axes = PPF_axis.shift(RIGHT*2).scale(0.8)
#
#         ppf_molly_graph = axes.plot(PPF_Molly, color=BLUE, x_range=(0, 45))
#         molly = Rectangle(height=3, width=3, color=BLUE).move_to(LEFT*4.5 + UP*2)
#         molly.z_index = 2
#         molly_name = Tex("Molly").scale(1.5).next_to(molly,LEFT,buff=-1/2).set_color(BLUE).rotate(np.pi/2)
#         molly_cost = Tex("$1C=9S$").next_to(molly,RIGHT,buff=-0.6).set_color(BLUE).rotate(np.pi/2)
#         molly_group = VGroup(molly,molly_name,molly_cost)
#
#         m_carrots = Rectangle(height=3/2, width=3, color=ORANGE, fill_opacity=1)
#         m_spinach = Rectangle(height=3/2, width=3, color=GREEN, fill_opacity=1)
#         molly_crops = VGroup(m_carrots,m_spinach.next_to(m_carrots,DOWN,buff=0)).move_to(molly)
#
#         ppf_andrew_graph = axes.plot(PPF_Andrew, color=RED, x_range=(0, 18))
#         andrew = Rectangle(height=3, width=3, color=RED).move_to(LEFT*4.5 + DOWN*2)
#         andrew.z_index = 2
#         andrew_name = Tex("Andrew").scale(1.5).next_to(andrew,LEFT,buff=-0.8).set_color(RED).rotate(np.pi/2)
#         andrew_cost = Tex("$1C=4.5S$").next_to(andrew,RIGHT,buff=-0.8).set_color(RED).rotate(np.pi/2)
#         andrew_group = VGroup(andrew,andrew_name,andrew_cost)
#
#         a_carrots = Rectangle(height=3/2, width=3, color=ORANGE, fill_opacity=1)
#         a_spinach = Rectangle(height=3/2, width=3, color=GREEN, fill_opacity=1)
#         andrew_crops = VGroup(a_carrots,a_spinach.next_to(a_carrots,DOWN,buff=0)).move_to(andrew)
#
#         """ Setup """
#
#         self.play(FadeIn(axes),FadeIn(molly_group),FadeIn(andrew_group))
#         self.wait()
#         self.play(Create(ppf_molly_graph))
#         self.wait()
#         self.play(Create(ppf_andrew_graph))
#         self.wait()
#
#         """ Setup The Guild """
#
#         p1m = axes.coords_to_point(22.5, 2.5)
#         p1a = axes.coords_to_point(9, 2)
#         p1g = axes.coords_to_point(31.5, 4.5)
#         dotm = Dot(p1m)
#         dota = Dot(p1a)
#         dotg = Dot(p1g)
#         self.play(FadeIn(dotm),FadeIn(molly_crops))
#         self.wait()
#         self.play(FadeIn(dota),FadeIn(andrew_crops))
#         self.wait()
#
#         guild_name = Tex("Guild PPF (no specialization)").scale(1.2).next_to(axes, UP).set_color(PURPLE)
#         self.play(AddTextWordByWord(guild_name), FadeIn(dotg))
#         self.wait()
#
#         """ Make The Guild's PPF """
#
#         m_carrots_new = Rectangle(height=3, width=3, color=ORANGE, fill_opacity=1)
#         m_spinach_new = Rectangle(height=0, width=3, color=GREEN, fill_opacity=1)
#         molly_crops_new = VGroup(m_carrots_new,m_spinach_new.next_to(m_carrots_new,DOWN,buff=0)).move_to(molly)
#         a_carrots_new = Rectangle(height=3, width=3, color=ORANGE, fill_opacity=1)
#         a_spinach_new = Rectangle(height=0, width=3, color=GREEN, fill_opacity=1)
#         andrew_crops_new = VGroup(a_carrots_new,a_spinach_new.next_to(a_carrots_new,DOWN,buff=0)).move_to(andrew)
#
#         p2m = axes.coords_to_point(0, 5)
#         p2a = axes.coords_to_point(0, 4)
#         p2g = axes.coords_to_point(0, 9)
#
#         self.play(dotm.animate.move_to(p2m),dota.animate.move_to(p2a),dotg.animate.move_to(p2g),
#                   Transform(molly_crops,molly_crops_new),Transform(andrew_crops,andrew_crops_new))
#
#         m_carrots_new = Rectangle(height=0, width=3, color=ORANGE, fill_opacity=1)
#         m_spinach_new = Rectangle(height=3, width=3, color=GREEN, fill_opacity=1)
#         molly_crops_new = VGroup(m_carrots_new,m_spinach_new.next_to(m_carrots_new,DOWN,buff=0)).move_to(molly)
#         a_carrots_new = Rectangle(height=0, width=3, color=ORANGE, fill_opacity=1)
#         a_spinach_new = Rectangle(height=3, width=3, color=GREEN, fill_opacity=1)
#         andrew_crops_new = VGroup(a_carrots_new,a_spinach_new.next_to(a_carrots_new,DOWN,buff=0)).move_to(andrew)
#
#         ppf_guild_graph = axes.plot(PPF_Guild, color=PURPLE, x_range=(0, 63), z_index=-1)
#
#         p2m = axes.coords_to_point(45, 0)
#         p2a = axes.coords_to_point(18, 0)
#         p2g = axes.coords_to_point(63, 0)
#         self.play(dotm.animate.move_to(p2m),dota.animate.move_to(p2a),dotg.animate.move_to(p2g),Create(ppf_guild_graph),
#                   Transform(molly_crops,molly_crops_new),Transform(andrew_crops,andrew_crops_new))
#         self.wait()
#
#         m_carrots_new = Rectangle(height=3/2, width=3, color=ORANGE, fill_opacity=1)
#         m_spinach_new = Rectangle(height=3/2, width=3, color=GREEN, fill_opacity=1)
#
#         molly_crops_new = VGroup(m_carrots_new,m_spinach_new.next_to(m_carrots_new,DOWN,buff=0)).move_to(molly)
#
#         a_carrots_new = Rectangle(height=3/2, width=3, color=ORANGE, fill_opacity=1)
#         a_spinach_new = Rectangle(height=3/2, width=3, color=GREEN, fill_opacity=1)
#         andrew_crops_new = VGroup(a_carrots_new,a_spinach_new.next_to(a_carrots_new,DOWN,buff=0)).move_to(andrew)
#
#         p2m = axes.coords_to_point(22.5, 2.5)
#         p2a = axes.coords_to_point(9, 2)
#         p2g = axes.coords_to_point(31.5, 4.5)
#         self.play(dotm.animate.move_to(p2m),dota.animate.move_to(p2a),dotg.animate.move_to(p2g),
#                   Transform(molly_crops,molly_crops_new),Transform(andrew_crops,andrew_crops_new))
#         self.wait()
#
#         new_guild_name = Tex("Guild PPF").scale(1.2).next_to(axes, UP).set_color(PURPLE)
#         self.play(Transform(guild_name, new_guild_name))
#
#         """ Show Comparative Advantage """
#
#         spinach_advantage = Tex("Spinach").rotate(np.pi/2).set_color(GREEN).next_to(molly_group,RIGHT)
#         self.play(AddTextWordByWord(spinach_advantage))
#         self.wait()
#         carrot_advantage = Tex("Carrots").rotate(np.pi/2).set_color(ORANGE).next_to(andrew_group,RIGHT)
#         self.play(AddTextWordByWord(carrot_advantage))
#         self.wait()
# Out:
# Manim Community v0.18.1
# <video src="PartA_E2/jupyter/animation_4@2024-08-27@23-14-31.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Animation 5 | Specialization In The Guild

# %%
# %%manim --transparent animation_5
#
# class animation_5(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         PPF_axis = Axes(
#             x_range=[0, 65, 5],
#             x_length = 7,
#             axis_config={"color": WHITE},
#             x_axis_config={
#                 "numbers_to_include": np.arange(0, 65, 15),
#                 "numbers_with_elongated_ticks": np.arange(0, 65, 10),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":GREEN,
#                 },
#             },
#             y_range=[0, 10, 1],
#             y_length = 6,
#             y_axis_config={
#                 "numbers_to_include": np.arange(0, 11, 2),
#                 "numbers_with_elongated_ticks": np.arange(0, 11, 5),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":ORANGE,
#                 }
#             },
#             tips=False,
#         )
#
#         """ Starting Objects """
#
#         axes = PPF_axis.shift(RIGHT*2).scale(0.8)
#
#         ppf_molly_graph = axes.plot(PPF_Molly, color=BLUE, x_range=(0, 45))
#         molly = Rectangle(height=3, width=3, color=BLUE).move_to(LEFT*4.5 + UP*2)
#         molly.z_index = 2
#         molly_name = Tex("Molly").scale(1.5).next_to(molly,LEFT,buff=-1/2).set_color(BLUE).rotate(np.pi/2)
#         molly_cost = Tex("$1C=9S$").next_to(molly,RIGHT,buff=-0.6).set_color(BLUE).rotate(np.pi/2)
#         molly_group = VGroup(molly,molly_name,molly_cost)
#
#         m_carrots = Rectangle(height=3/2, width=3, color=ORANGE, fill_opacity=1)
#         m_spinach = Rectangle(height=3/2, width=3, color=GREEN, fill_opacity=1)
#         molly_crops = VGroup(m_carrots,m_spinach.next_to(m_carrots,DOWN,buff=0)).move_to(molly)
#
#         ppf_andrew_graph = axes.plot(PPF_Andrew, color=RED, x_range=(0, 18))
#         andrew = Rectangle(height=3, width=3, color=RED).move_to(LEFT*4.5 + DOWN*2)
#         andrew.z_index = 2
#         andrew_name = Tex("Andrew").scale(1.5).next_to(andrew,LEFT,buff=-0.8).set_color(RED).rotate(np.pi/2)
#         andrew_cost = Tex("$1C=4.5S$").next_to(andrew,RIGHT,buff=-0.8).set_color(RED).rotate(np.pi/2)
#         andrew_group = VGroup(andrew,andrew_name,andrew_cost)
#
#         a_carrots = Rectangle(height=3/2, width=3, color=ORANGE, fill_opacity=1)
#         a_spinach = Rectangle(height=3/2, width=3, color=GREEN, fill_opacity=1)
#         andrew_crops = VGroup(a_carrots,a_spinach.next_to(a_carrots,DOWN,buff=0)).move_to(andrew)
#
#         ppf_guild_graph = axes.plot(PPF_Guild, color=PURPLE, x_range=(0, 63))
#
#         p1m = axes.coords_to_point(22.5, 2.5)
#         p1a = axes.coords_to_point(9, 2)
#         p1g = axes.coords_to_point(31.5, 4.5)
#         dotm = Dot(p1m)
#         dotm.z_index = 2
#         dota = Dot(p1a)
#         dota.z_index = 2
#         dotg = Dot(p1g)
#         dotg.z_index = 2
#
#         guild_name = Tex("Guild PPF").scale(1.2).next_to(axes, UP).set_color(PURPLE)
#
#         spinach_advantage = Tex("Spinach").rotate(np.pi/2).set_color(GREEN).next_to(molly_group,RIGHT)
#         carrot_advantage = Tex("Carrots").rotate(np.pi/2).set_color(ORANGE).next_to(andrew_group,RIGHT)
#
#         """ Setup """
#         self.add(dotm,dota,dotg,spinach_advantage,carrot_advantage)
#         self.add(axes,molly_group,molly_crops,andrew_group,andrew_crops,ppf_molly_graph,ppf_andrew_graph,guild_name,ppf_guild_graph)
#         self.wait()
#
#         """ Show Comparative Advantages """
#
#         molly_ad = axes.coords_to_point(45,0)
#         molly_ad = Dot(molly_ad, radius=0.2, stroke_width=0, fill_opacity=0.3, color='WHITE')
#         molly_ad.z_index = 0
#
#         andrew_ad = axes.coords_to_point(0,4)
#         andrew_ad = Dot(andrew_ad, radius=0.2, stroke_width=0, fill_opacity=0.3, color='WHITE')
#         andrew_ad.z_index = 0
#
#         self.play(FadeIn(molly_ad),FadeIn(andrew_ad))
#         self.wait()
#
#         """ Specialize """
#
#         alpha_pairs = [[1,0],[0,1]]
#         for pair in alpha_pairs:
#             alpha_m = pair[0]
#             alpha_a = pair[1]
#
#             m_carrots_new = Rectangle(height=alpha_m*3, width=3, color=ORANGE, fill_opacity=1)
#             m_spinach_new = Rectangle(height=(1-alpha_m)*3, width=3, color=GREEN, fill_opacity=1)
#             molly_crops_new = VGroup(m_carrots_new,m_spinach_new.next_to(m_carrots_new,DOWN,buff=0)).move_to(molly)
#
#             a_carrots_new = Rectangle(height=alpha_a*3, width=3, color=ORANGE, fill_opacity=1)
#             a_spinach_new = Rectangle(height=(1-alpha_a)*3, width=3, color=GREEN, fill_opacity=1)
#             andrew_crops_new = VGroup(a_carrots_new,a_spinach_new.next_to(a_carrots_new,DOWN,buff=0)).move_to(andrew)
#
#             p2m = axes.coords_to_point(45*(1-alpha_m), 5*alpha_m)
#             p2a = axes.coords_to_point(18*(1-alpha_a), 4*alpha_a)
#             p2g = axes.coords_to_point(45*(1-alpha_m)+18*(1-alpha_a), 5*alpha_m+4*alpha_a)
#
#             self.play(dotm.animate.move_to(p2m),dota.animate.move_to(p2a),dotg.animate.move_to(p2g),
#                       Transform(molly_crops,molly_crops_new),Transform(andrew_crops,andrew_crops_new))
#             self.wait()
#
#         """ Trace The Specialized Guild """
#
#         path = VMobject(color=PINK)
#         path.set_points_as_corners([dotg.get_center(), dotg.get_center()])
#         def update_path(path):
#             previous_path = path.copy()
#             previous_path.add_points_as_corners([dotg.get_center()])
#             path.become(previous_path)
#         path.add_updater(update_path)
#         self.add(path, dotg)
#
#         self.play(ppf_guild_graph.animate.set_opacity(0.1))
#
#         alpha_pairs = [[1,1],[0,1],[0,0]]
#         for pair in alpha_pairs:
#             alpha_m = pair[0]
#             alpha_a = pair[1]
#
#             m_carrots_new = Rectangle(height=alpha_m*3, width=3, color=ORANGE, fill_opacity=1)
#             m_spinach_new = Rectangle(height=(1-alpha_m)*3, width=3, color=GREEN, fill_opacity=1)
#             molly_crops_new = VGroup(m_carrots_new,m_spinach_new.next_to(m_carrots_new,DOWN,buff=0)).move_to(molly)
#
#             a_carrots_new = Rectangle(height=alpha_a*3, width=3, color=ORANGE, fill_opacity=1)
#             a_spinach_new = Rectangle(height=(1-alpha_a)*3, width=3, color=GREEN, fill_opacity=1)
#             andrew_crops_new = VGroup(a_carrots_new,a_spinach_new.next_to(a_carrots_new,DOWN,buff=0)).move_to(andrew)
#
#             p2m = axes.coords_to_point(45*(1-alpha_m), 5*alpha_m)
#             p2a = axes.coords_to_point(18*(1-alpha_a), 4*alpha_a)
#             p2g = axes.coords_to_point(45*(1-alpha_m)+18*(1-alpha_a), 5*alpha_m+4*alpha_a)
#
#             self.play(dotm.animate.move_to(p2m),dota.animate.move_to(p2a),dotg.animate.move_to(p2g),
#                       Transform(molly_crops,molly_crops_new),Transform(andrew_crops,andrew_crops_new))
#             self.wait(1/10)
#
#         """ Show Gains From Specialization """
#
#         a = axes.coords_to_point(63, 0)
#         b = axes.coords_to_point(45, 4)
#         c = axes.coords_to_point(0, 9)
#
#         gains = Polygon(a,b,c, color=PINK, fill_opacity=1)
#         gains.z_index = 0
#         gains_text = Tex('Gains From Specialization').scale(1.2).set_color(PINK).next_to(gains, UP*3).shift(RIGHT/2)
#
#         self.play(FadeOut(guild_name),FadeIn(gains),FadeIn(gains_text))
#         self.wait()
#
#         """ Do More Pairs """
#
#         alpha_pairs = [[0,1],[0.1,1],[0.2,1],[0.3,1],[0.4,1],[0.5,1],[0.6,1],[0.7,1],[0.8,1],[0.9,1],[1,1]] + [[0,0.9],[0,0.8],[0,0.7],[0,0.6],[0,0.5],[0,0.4],[0,0.3],[0,0.2],[0,0.1],[0,0]]
#         random.shuffle(alpha_pairs)
#         for pair in alpha_pairs:
#             alpha_m = pair[0]
#             alpha_a = pair[1]
#
#             m_carrots_new = Rectangle(height=alpha_m*3, width=3, color=ORANGE, fill_opacity=1)
#             m_spinach_new = Rectangle(height=(1-alpha_m)*3, width=3, color=GREEN, fill_opacity=1)
#             molly_crops_new = VGroup(m_carrots_new,m_spinach_new.next_to(m_carrots_new,DOWN,buff=0)).move_to(molly)
#
#             a_carrots_new = Rectangle(height=alpha_a*3, width=3, color=ORANGE, fill_opacity=1)
#             a_spinach_new = Rectangle(height=(1-alpha_a)*3, width=3, color=GREEN, fill_opacity=1)
#             andrew_crops_new = VGroup(a_carrots_new,a_spinach_new.next_to(a_carrots_new,DOWN,buff=0)).move_to(andrew)
#
#             p2m = axes.coords_to_point(45*(1-alpha_m), 5*alpha_m)
#             p2a = axes.coords_to_point(18*(1-alpha_a), 4*alpha_a)
#             p2g = axes.coords_to_point(45*(1-alpha_m)+18*(1-alpha_a), 5*alpha_m+4*alpha_a)
#
#             self.play(dotm.animate.move_to(p2m),dota.animate.move_to(p2a),dotg.animate.move_to(p2g),
#                       Transform(molly_crops,molly_crops_new),Transform(andrew_crops,andrew_crops_new))
#             self.wait(1/10)
#
#         self.wait()
# Out:
# Manim Community v0.18.1
# <video src="PartA_E2/jupyter/animation_5@2024-08-30@19-33-41.mov" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Animation 6 | Many Sellers
#
# This animation shows that as you add more sellers the PPF with trade bows outward.
#
# Outline
# - Take Andrew and Molly and plot their costs as two points on a graph
# - Then add one point at a time and show the effect on the guild ppf

# %% [markdown]
# ### Merge and Convert Videos

# %%
from Video import *

video_path = config.media_dir+'/videos/ANIMATIONS/1080p10/'

Make_MOV(video_path)
# Out:
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x135811800] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'concat.txt':
#   Duration: N/A, start: 0.000000, bitrate: 671 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 671 kb/s, 10.12 fps, 10 tbr, 10240 tbn, 20 tbc
#     Metadata:
#       handler_name    : VideoHandler
# Output #0, mp4, to 'PartA_E2/videos/ANIMATIONS/1080p10/./media.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, q=2-31, 671 kb/s, 10.12 fps, 10 tbr, 10240 tbn, 10240 tbc
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x135811800] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x137008200] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 1 times
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x135811800] Auto-inserting h264_mp4toannexb bitstream filter
# frame= 1348 fps=0.0 q=-1.0 Lsize=    7746kB time=00:02:14.50 bitrate= 471.8kbits/s speed=6.03e+03x
# video:7728kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.228031%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'PartA_E2/videos/ANIMATIONS/1080p10/animation_3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     comment         : Rendered with Manim Community v0.18.1
#   Duration: 00:00:28.80, start: 0.000000, bitrate: 345 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 344 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x119038000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mov, to 'PartA_E2/videos/ANIMATIONS/1080p10/animation_3_convert.mov':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.18.1
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mjpeg (jpeg / 0x6765706A), yuvj420p(pc), 2160x1080, q=2-31, 200 kb/s, 10 fps, 10240 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  288 fps=0.0 q=2.0 Lsize=   27087kB time=00:00:28.70 bitrate=7731.6kbits/s speed=39.9x
# video:27085kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.007990%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'PartA_E2/videos/ANIMATIONS/1080p10/animation_2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     comment         : Rendered with Manim Community v0.18.1
#   Duration: 00:00:26.00, start: 0.000000, bitrate: 440 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 439 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1481d0000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mov, to 'PartA_E2/videos/ANIMATIONS/1080p10/animation_2_convert.mov':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.18.1
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mjpeg (jpeg / 0x6765706A), yuvj420p(pc), 2160x1080, q=2-31, 200 kb/s, 10 fps, 10240 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  260 fps=0.0 q=2.0 Lsize=   27282kB time=00:00:25.90 bitrate=8628.9kbits/s speed=40.2x
# video:27279kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.007589%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'PartA_E2/videos/ANIMATIONS/1080p10/media.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:02:14.80, start: 0.000000, bitrate: 470 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 470 kb/s, 10.01 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x121078000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mov, to 'PartA_E2/videos/ANIMATIONS/1080p10/media_convert.mov':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mjpeg (jpeg / 0x6765706A), yuvj420p(pc), 2160x1080, q=2-31, 200 kb/s, 10 fps, 10240 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame= 1348 fps=407 q=2.0 Lsize=  141047kB time=00:02:14.70 bitrate=8578.0kbits/s speed=40.7x
# video:141040kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004978%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'PartA_E2/videos/ANIMATIONS/1080p10/animation_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     comment         : Rendered with Manim Community v0.18.1
#   Duration: 00:00:17.10, start: 0.000000, bitrate: 665 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 671 kb/s, 10.12 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x138398000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mov, to 'PartA_E2/videos/ANIMATIONS/1080p10/animation_0_convert.mov':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.18.1
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mjpeg (jpeg / 0x6765706A), yuvj420p(pc), 2160x1080, q=2-31, 200 kb/s, 10 fps, 10240 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  171 fps=0.0 q=2.0 Lsize=   14258kB time=00:00:17.00 bitrate=6870.6kbits/s speed=39.1x
# video:14256kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.011042%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'PartA_E2/videos/ANIMATIONS/1080p10/animation_1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     comment         : Rendered with Manim Community v0.18.1
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 94 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 91 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x120cc8000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mov, to 'PartA_E2/videos/ANIMATIONS/1080p10/animation_1_convert.mov':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.18.1
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mjpeg (jpeg / 0x6765706A), yuvj420p(pc), 2160x1080, q=2-31, 200 kb/s, 10 fps, 10240 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=   30 fps=0.0 q=2.0 Lsize=     760kB time=00:00:02.90 bitrate=2146.1kbits/s speed=34.9x
# video:759kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.121486%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'PartA_E2/videos/ANIMATIONS/1080p10/animation_5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     comment         : Rendered with Manim Community v0.18.1
#   Duration: 00:00:37.40, start: 0.000000, bitrate: 624 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 623 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x129230000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mov, to 'PartA_E2/videos/ANIMATIONS/1080p10/animation_5_convert.mov':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.18.1
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mjpeg (jpeg / 0x6765706A), yuvj420p(pc), 2160x1080, q=2-31, 200 kb/s, 10 fps, 10240 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  374 fps=0.0 q=2.0 Lsize=   49487kB time=00:00:37.30 bitrate=10868.6kbits/s speed=38.5x
# video:49485kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005076%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'PartA_E2/videos/ANIMATIONS/1080p10/animation_4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     comment         : Rendered with Manim Community v0.18.1
#   Duration: 00:00:22.50, start: 0.000000, bitrate: 313 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 312 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x120de8000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mov, to 'PartA_E2/videos/ANIMATIONS/1080p10/animation_4_convert.mov':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.18.1
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mjpeg (jpeg / 0x6765706A), yuvj420p(pc), 2160x1080, q=2-31, 200 kb/s, 10 fps, 10240 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  225 fps=0.0 q=2.0 Lsize=   22177kB time=00:00:22.40 bitrate=8110.5kbits/s speed=38.3x
# video:22175kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.008402%
# rm: PartA_E2/videos/ANIMATIONS/1080p10/./media.mov: No such file or directory
