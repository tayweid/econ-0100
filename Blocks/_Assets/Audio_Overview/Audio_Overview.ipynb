# %%
from Video import *
warnings.filterwarnings('ignore')

""" Paths """
tutorial_path = 'PartB_E1'
if not os.path.exists(tutorial_path):
    os.makedirs(tutorial_path)
config.media_dir = tutorial_path
config.verbosity = 'ERROR'

""" Colors """
CUSTOM_BLACK = '#1f1f1f'
CUSTOM_GREY = '#696969'
DEFINITION = '#FFD700'
config.background_color = CUSTOM_BLACK
config.axes_color = CUSTOM_GREY

""" Frames """
PIXEL_HEIGHT = 1080
FPS = 10
config.pixel_height = PIXEL_HEIGHT
config.pixel_width = PIXEL_HEIGHT*2
config.frame_rate = FPS

# %% [markdown]
# ## This animation is meant to be the visual for the audio overview podcast.

# %% [markdown]
# ## Chapter 1

# %%
# %%manim ch1_overview_0
#
# class ch1_overview_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part A}} $|$ Chapter 1').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part A": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label)
#         self.play(FadeIn(part_label), group.animate.move_to(0))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch1_overview_0@2024-10-04@13-40-57.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ch1_overview_1
#
# class ch1_overview_1(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         squares = [s.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#         Squares = VGroup(*squares)
#
#         part_label = Tex('{{Part A}} $|$ Chapter 1').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part A": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label).move_to(0)
#
#         self.add(Squares, group)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch1_overview_1@2024-10-04@13-40-35.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Chapter 2

# %%
# %%manim ch2_overview_0
#
# class ch2_overview_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part A}} $|$ Chapter 2').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part A": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label)
#         self.play(FadeIn(part_label), group.animate.move_to(0))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch2_overview_0@2024-10-04@13-40-27.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ch2_overview_1
#
# class ch2_overview_1(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         squares = [s.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#         Squares = VGroup(*squares)
#
#         part_label = Tex('{{Part A}} $|$ Chapter 2').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part A": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label).move_to(0)
#
#         self.add(Squares, group)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch2_overview_1@2024-10-04@13-40-05.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Chapter 3

# %%
# %%manim ch3_overview_0
#
# class ch3_overview_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part A}} $|$ Chapter 3').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part A": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label)
#         self.play(FadeIn(part_label), group.animate.move_to(0))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch3_overview_0@2024-10-04@13-39-56.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ch3_overview_1
#
# class ch3_overview_1(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         squares = [s.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#         Squares = VGroup(*squares)
#
#         part_label = Tex('{{Part A}} $|$ Chapter 3').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part A": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label).move_to(0)
#
#         self.add(Squares, group)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch3_overview_1@2024-10-04@13-39-35.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Chapter 4

# %%
# %%manim ch4_overview_0
#
# class ch4_overview_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part B}} $|$ Chapter 4').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part B": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label)
#         self.play(FadeIn(part_label), group.animate.move_to(0))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch4_overview_0@2024-10-04@13-39-26.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ch4_overview_1
#
# class ch4_overview_1(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         squares = [s.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#         Squares = VGroup(*squares)
#
#         part_label = Tex('{{Part B}} $|$ Chapter 4').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part B": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label).move_to(0)
#
#         self.add(Squares, group)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch4_overview_1@2024-10-04@13-39-05.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Chapter 5

# %%
# %%manim ch5_overview_0
#
# class ch5_overview_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part B}} $|$ Chapter 5').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part B": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label)
#         self.play(FadeIn(part_label), group.animate.move_to(0))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch5_overview_0@2024-10-04@13-38-56.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ch5_overview_1
#
# class ch5_overview_1(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         squares = [s.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#         Squares = VGroup(*squares)
#
#         part_label = Tex('{{Part B}} $|$ Chapter 5').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part B": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label).move_to(0)
#
#         self.add(Squares, group)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch5_overview_1@2024-10-04@13-38-34.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Chapter 6

# %%
# %%manim ch6_overview_0
#
# class ch6_overview_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part B}} $|$ Chapter 6').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part B": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label)
#         self.play(FadeIn(part_label), group.animate.move_to(0))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch6_overview_0@2024-10-04@13-38-26.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ch6_overview_1
#
# class ch6_overview_1(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         squares = [s.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#         Squares = VGroup(*squares)
#
#         part_label = Tex('{{Part B}} $|$ Chapter 6').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part B": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label).move_to(0)
#
#         self.add(Squares, group)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch6_overview_1@2024-10-04@13-38-04.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Chapter 7

# %%
# %%manim ch7_overview_0
#
# class ch7_overview_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part B}} $|$ Chapter 7').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part B": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label)
#         self.play(FadeIn(part_label), group.animate.move_to(0))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch7_overview_0@2024-10-04@13-37-56.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ch7_overview_1
#
# class ch7_overview_1(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         squares = [s.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#         Squares = VGroup(*squares)
#
#         part_label = Tex('{{Part B}} $|$ Chapter 7').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part B": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label).move_to(0)
#
#         self.add(Squares, group)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch7_overview_1@2024-10-04@13-37-34.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Chapter 9

# %%
# %%manim ch9_overview_0
#
# class ch9_overview_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part B}} $|$ Chapter 9').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part B": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label)
#         self.play(FadeIn(part_label), group.animate.move_to(0))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch9_overview_0@2024-10-04@13-37-25.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ch9_overview_1
#
# class ch9_overview_1(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         squares = [s.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#         Squares = VGroup(*squares)
#
#         part_label = Tex('{{Part B}} $|$ Chapter 9').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part B": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label).move_to(0)
#
#         self.add(Squares, group)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch9_overview_1@2024-10-04@13-37-04.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Chapter 8

# %%
# %%manim ch8_overview_0
#
# class ch8_overview_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part C}} $|$ Chapter 8').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part C": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label)
#         self.play(FadeIn(part_label), group.animate.move_to(0))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch8_overview_0@2024-10-04@13-36-55.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ch8_overview_1
#
# class ch8_overview_1(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         squares = [s.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#         Squares = VGroup(*squares)
#
#         part_label = Tex('{{Part C}} $|$ Chapter 8').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part C": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label).move_to(0)
#
#         self.add(Squares, group)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch8_overview_1@2024-10-04@13-36-33.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Chapter 10

# %%
# %%manim ch10_overview_0
#
# class ch10_overview_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part C}} $|$ Chapter 10').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part C": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label)
#         self.play(FadeIn(part_label), group.animate.move_to(0))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch10_overview_0@2024-10-04@13-36-25.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ch10_overview_1
#
# class ch10_overview_1(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         squares = [s.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#         Squares = VGroup(*squares)
#
#         part_label = Tex('{{Part C}} $|$ Chapter 10').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part C": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label).move_to(0)
#
#         self.add(Squares, group)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch10_overview_1@2024-10-04@13-36-03.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Chapter 12

# %%
# %%manim ch12_overview_0
#
# class ch12_overview_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part C}} $|$ Chapter 12').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part C": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label)
#         self.play(FadeIn(part_label), group.animate.move_to(0))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch12_overview_0@2024-10-04@13-35-55.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ch12_overview_1
#
# class ch12_overview_1(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         squares = [s.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#         Squares = VGroup(*squares)
#
#         part_label = Tex('{{Part C}} $|$ Chapter 12').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part C": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label).move_to(0)
#
#         self.add(Squares, group)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch12_overview_1@2024-10-04@13-35-33.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Chapter 11

# %%
# %%manim ch11_overview_0
#
# class ch11_overview_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part D}} $|$ Chapter 11').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part D": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label)
#         self.play(FadeIn(part_label), group.animate.move_to(0))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch11_overview_0@2024-10-04@13-35-25.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim ch11_overview_1
#
# class ch11_overview_1(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         squares = [s.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#         Squares = VGroup(*squares)
#
#         part_label = Tex('{{Part D}} $|$ Chapter 11').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part D": BLUE,}
#         ).scale(3).next_to(Squares, DOWN*4)
#         group = VGroup(Squares, part_label).move_to(0)
#
#         self.add(Squares, group)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
# Out:
# Manim Community v0.18.1
# <video src="PartB_E1/jupyter/ch11_overview_1@2024-10-04@13-35-03.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### Merge and Convert Videos

# %%
video_path = config.media_dir+'/videos/Videos/1080p10/'

Make_MOV(video_path)
