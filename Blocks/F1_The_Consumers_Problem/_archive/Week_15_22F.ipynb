# %%
from lectures import *
# %matplotlib inline
warnings.filterwarnings('ignore')

file_name = 'timeline'
title = '\\textbf{Intro Micro | Week 14}'
subtitle = ''
author = ''#'Taylor J. Weidman'

export_the_file([file_name, title, subtitle, author])
# Out:
# [NbConvertApp] Converting notebook file_to_convert.ipynb to pdf
# [NbConvertApp] Writing 21294 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 15989 bytes to timeline_week12.pdf

# %% [markdown]
# # Week 15 | The Consumer's Problem

# %% [markdown]
# ## Introduction to the Week
#
# Welcome back from break. I hope you had a restful and relaxing time away. This is the second to last week of the semester and, excitingly, we have two more topics to cover.
#
# So far we've looked at markets for final goods: goods that go toward what we often call "consumption", goods that aren't used to do anything necessarily productive. On Tuesday, however, we're covering markets for inputs into the production process of other goods. We'll look at the labor market, think about what happens to prices when external shocks like a pandemic shock the labor supply, and then close out by considering the market for the second type of input in the production process: capital.
#
# On Thursday we'll begin two classes covering our final topic: utility and an individual's tradeoffs. This is often called "The Theory of Consumer Choice". When you walk into a store with $5 to spend, you're confronted with many ways to spend your money, some better than others. So how should you choose what to buy when you have tradeoffs? The answer to this question gives us a peek into the workings behind the demand curve. And if you're already thinking about opportunity cost, you're on the right track.
#
# ## Tutorials
#
# No tutorials this week.
#
# ## Reading
#
# - Chapter 18. Factor Markets
# - Chapter 21. Consumer Theory

# %% [markdown]
# ## Class 2 | The Consumer's Problem
#
# ### Outline
# - Preferences
# - Indifference curves, substitutability
# - Square root indifference curve
# - Utility function, hold the vertical constant and stack indifference curves, incrementing by 1
# - Marginal Utility
# - Marginal Rate of Substitution
# - Marginal Utility Example: Starbucks Coffee Sizes
# - Budget Constraint
# - Marginal Rate of Transformation
# - Constrained Choice
# - Changes in income
# - Changes in price
# - Deriving the demand curve
# - Income and substitution effects

# %% [markdown]
# ## Class 1 |

# %% [markdown]
# ## Class 2 |

# %% [markdown]
# # Last Class
#
# So what have we done?
#
# The big questions we've aimed at are twofold:
# 1. What is possible for us to achieve?
# 2. And how to we distribute what we've achieved?
#
# To do this we started by introducing the basic problem:
