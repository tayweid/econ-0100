# %%
from Lectures import *
# %matplotlib inline
warnings.filterwarnings('ignore')

file_name = 'Week_01'
title = '\\textbf{Intro Microeconomics | Week 1}'
subtitle = ''
author = 'Taylor J. Weidman'

export_the_file([file_name, title, subtitle, author])
# Out:
# [NbConvertApp] Converting notebook file_to_convert.ipynb to pdf
# [NbConvertApp] Writing 26267 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 27120 bytes to Week_01.pdf

# %% [markdown]
# # Week 1 | The Landscape

# %% [markdown]
# ## Introduction to the Week
#
# Our first week of class will be a busy one.
#
# - Tuesday I will outline the main topics for the class, explain how the class is structured and why I have structured it that way. This is an important day... we will start discussing why the class is so important!
#
# - Thursday we will build our first economic model: the Production Possibility Frontier. While it is a very simple model, it's really the backbone of why we might care about economics in the first place, and offers some unintuitive and fundamental insights.

# %% [markdown]
# ## Week 1 | Welcome to Microeconomics!

# %% [markdown]
# Hi folks,
#
# Nice having everyone in class this week! I always get excited for the semester this time of year. Week 1 is a time to become familiar with the class, the people in the class, and where we're going this semester. Economics is a hugely important field across many domains and I'm glad you're part of what we're doing this fall.
#
# Homework A is posted, due on Friday September 2 (a week from tomorrow). We've just started examining the tools to approach the assignment. Feel free to get started. But also know it might be tough until we do a little more work. I'd recommend starting on Tuesday after class.
#
# Week 1 can be a little difficult staying on top of everything since we're just getting going. So if you haven't finished the reading you're doing fine. But starting Week 2 its best to come to class having at least skimmed the reading. Make sure you've read Chapters 1, 2, and 3 by class on Tuesday. These chapters are crucial to the class.
#
# See you in class!
#
# Taylor

# %% [markdown]
# ## Reading
#
# - Chapter 1.
# - Chapter 2.
# - Chapter 3.

# %% [markdown]
# ## Tutorials
#
# - Tutorial 01.A | Preferences + Scarcity = Choices
# - Tutorial 01.B | Opportunity Cost
# - Tutorial 01.C | PPF
# - Tutorial 01.D | PPF and Shifts in Labor and Technology
# - Tutorial 01.D | Gains from Specialization

# %% [markdown]
# ## Class 1 | Introductions

# %% [markdown]
# This is a great class. I took it my first year in undergrad. Saying it changed my life is maybe a bit hyperbolic. But the ideas are very deep in a way that really inspired me. If you’ve been on the fence, you made the right choice. In this room I’m going to challenge you and you’re going to leave with a much deeper understanding of the way the world works.
#
# I took this class my first year of college. I was originally an engineering major, but in large part because of a big ahha moment we’ll talk through later in the semester, I added Economics as a major. Every semester when choosing classes to teach, I jockey for this one. I love this class and how it forms a foundational framework. One thing most people don’t tell you is that everyone in this building could take non-teaching jobs somewhere else. But teaching this material is so fun it’s worth it.
#
# Before we go around and introduce ourselves, we’re going to do the first of many in-class simulations to demonstrate a core principle of economics.
#
# Simulation:
# Grading takes work and I like doing as little of it as possible. Who would be willing to skip every assignment in exchange for a guaranteed C? What about a guaranteed A?
#
# This is confusing….
#
# “People respond to incentives.”
#
# We’re going to get to some more economics today. But this is the principle behind grades in this class.
#
# Grading isn’t fun for anyone. I don’t like giving bad grades and you don’t like getting them. We can run classes without grades, but it's difficult. And you will almost certainly get less out of it. I build classrooms that are less focussed on the grade. I expect you to be here every class barring emergencies, and one “I need a day off” day. I expect you to want to be here, want to learn what we’re doing together, put in the time outside class to master what we’re doing, and work in good faith. I wish I could drop all graded components of the class. But I’m not going to. Practice is good, feedback is good, and accountability is good. If you’re stressing about the grade you’re going to get in the class, you’re almost certainly doing this class wrong.
#
# I want you to feel pressure to put in the work, to dig into the material, to go the extra mile. But I don’t want you to feel that pressure from me. I want you to buy into the structure, to hand the assignment to yourself, and then ask me for feedback by turning it in. That feedback will be in the form of comments on your graded work along with a grade. But if you’re getting a D- or if you’re getting a A+ in the class, you’ll receive the same level of respect, admiration as a human, and feedback on your work.
#
# I care about your grade in the sense that I want you to follow through on your commitment to yourself to learn economics. But I also don’t care what your grade is in the sense that students good at economics are no more worthy than those who aren't.
#
# If you’re struggling I need you to promise you’ll reach out to me. I aim to do the same, although you have to recognize I have a lot of students. So lets share the responsibility to make sure that you are staying current, getting what you need, and doing well.
#
# Let's do some introductions.
#
# **introductions**
#
# There are six Homeworks. You’re STRONGLY encouraged to work in groups. I’d go as far as to say that if you’re not working on homework in a group, you’re not doing this class right. This is so true, that I want you to get the names of three others in the class and add them to the lines in your syllabus. By putting your name down in someone’s syllabus, you’re giving them the authorization to contact you with questions about the class at any point, whether you’ve been in touch recently, or not.
#
# These are your microeconomics peer mentors. You don’t need to be in touch with them or even be friends. But you have them at the very least as a backup in case you get stuck.
#
# And there are six Miniexams, which look a lot like Homework, just timed. They’re open book, open note, silent, and in airplane mode.
#
# Classwork happens during the first five minutes of every class on Tuesday when there’s not a Miniexam. This is a small part of your grade, but you’ll get immediate feedback, and will help keep you on track.
#
# All assignments are submitted via Box. You’ll need the Box app on Thursday. If this is a problem for you, let me know and we can find something that works. There’s a document scanner built into the app. You’ll complete the assignment inside the app and then scan any written work using the scanner. Both count. I care mostly about your process. If your process is off, the assignment will be off. When this happens, and it will happen for everyone here, I want to be able to check your process.
#
# I review material right after the due date. Quick feedback is better. But it makes it difficult to accept late work. I would prefer a world where you could turn in work at any point you’d like. But there are technical constraints that make it difficult.
#
# The class is held together on Blackboard and my website, which we’ll talk more about in a later class. I reserve the right to modify anything in the syllabus. You’ll be made aware via Blackboard and in class.
#
# Signing this syllabus is a contract with yourself. You’re agreeing to assign yourself the reading, showing up to class, Classwork, 6 Homeworks, and 6 Miniexams.
#
# Our time in class will be a mixture of Lectures, Vignettes, Simulations, and MiniExams.

# %% [markdown]
# ## Class 2 | The PPF in Ernest
