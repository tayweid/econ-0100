# %%
from Video import *
warnings.filterwarnings('ignore')

""" Paths """
tutorial_path = 'PartA_E3'
if not os.path.exists(tutorial_path):
    os.makedirs(tutorial_path)
config.media_dir = tutorial_path
config.verbosity = 'ERROR'

""" Colors """
CUSTOM_BLACK = '#1f1f1f'
CUSTOM_GREY = '#696969'
DEFINITION = '#FFD700'
config.background_color = CUSTOM_BLACK
config.axes_color = CUSTOM_GREY

""" Frames """
PIXEL_HEIGHT = 1080
FPS = 10
config.pixel_height = PIXEL_HEIGHT
config.pixel_width = PIXEL_HEIGHT*2
config.frame_rate = FPS

# %% [markdown]
# # Coordination with trade! | Part A | Episode 3

# %% [markdown]
# ## Animation 0 | Intro Sequence

# %%
# %%manim animation_0
#
# class animation_0(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         colors = sns.color_palette("Blues", 50).as_hex()
#
#         size = 1/6
#         n_width = 2
#         n_height = 3
#
#         n_rows = len(range(-n_height,n_height+1))
#         n_cols = len(range(-n_width,n_width+1))
#         w_list = list(range(-n_width,n_width+1))*n_rows
#         h_list = [i for i in range(-n_height,n_height+1) for x in 'a'*n_cols]
#         block = list(zip(w_list,h_list)) # height: 7, width: 5
#
#         string = 'MICROECONOMICS'
#         letters = [raster_font[l] for l in string]
#
#         """ Run """
#
#         shift = 0
#         centering = -39
#         squares = []
#         for l in letters:
#             s = [Square(side_length=size, color=config.background_color).move_to(RIGHT*(w + shift*6 + centering)*size + DOWN*h*size) for w,h in [block[i] for i in l]]
#             squares = squares + s
#             shift = shift + 1
#
#         Squares = VGroup(*squares)
#
#         self.add(Squares)
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         part_label = Tex('{{Part A}} $|$ Episode 3').set_color(GREY).set_color_by_tex_to_color_map(
#             {"Part A": BLUE,}
#         ).scale(3).move_to(DOWN)
#         self.play(AddTextWordByWord(part_label), Squares.animate.to_edge(UP, buff=1))
#
#         for i in range(15):
#             update_squares = [s.animate.set_fill(random.sample(colors,1),opacity=1) for s in squares]
#             self.play(*update_squares, run_time=1/10)
#             self.wait(4/10)
#
#         self.wait()
# Out:
# Manim Community v0.18.1
# <video src="PartA_E3/jupyter/animation_0@2024-09-04@09-36-00.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Animation 1 | Last Time...

# %%
# %%manim animation_1
#
# class animation_1(Scene):
#
#     def construct(self):
#         text = Tex('Last Time...').scale(3)
#         self.play(FadeIn(text), run_time=1/2)
#         self.wait()
#         self.play(FadeOut(text), run_time=1/2)
#         self.wait()
# Out:
# Manim Community v0.18.1
# <video src="PartA_E3/jupyter/animation_1@2024-09-04@09-36-01.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Animation 2 | The Specialized Guild

# %%
# %%manim animation_2
#
# class animation_2(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         PPF_axis = Axes(
#             x_range=[0, 65, 5],
#             x_length = 7,
#             axis_config={"color": WHITE},
#             x_axis_config={
#                 "numbers_to_include": np.arange(0, 65, 15),
#                 "numbers_with_elongated_ticks": np.arange(0, 65, 10),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":GREEN,
#                 },
#             },
#             y_range=[0, 10, 1],
#             y_length = 6,
#             y_axis_config={
#                 "numbers_to_include": np.arange(0, 11, 2),
#                 "numbers_with_elongated_ticks": np.arange(0, 11, 5),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":ORANGE,
#                 }
#             },
#             tips=False,
#         )
#
#         """ Starting Objects """
#
#         axes = PPF_axis.shift(RIGHT*2).scale(0.8)
#
#         ppf_molly_graph = axes.plot(PPF_Molly, color=BLUE, x_range=(0, 45))
#         molly = Rectangle(height=3, width=3, color=BLUE).move_to(LEFT*4.5 + UP*2)
#         molly.z_index = 2
#         molly_name = Tex("Molly").scale(1.5).next_to(molly,LEFT,buff=-1/2).set_color(BLUE).rotate(np.pi/2)
#         molly_cost = Tex("$1C=9S$").next_to(molly,RIGHT,buff=-0.6).set_color(BLUE).rotate(np.pi/2)
#         molly_group = VGroup(molly,molly_name,molly_cost)
#
#         m_carrots = Rectangle(height=3/2, width=3, color=ORANGE, fill_opacity=1)
#         m_spinach = Rectangle(height=3/2, width=3, color=GREEN, fill_opacity=1)
#         molly_crops = VGroup(m_carrots,m_spinach.next_to(m_carrots,DOWN,buff=0)).move_to(molly)
#
#         ppf_andrew_graph = axes.plot(PPF_Andrew, color=RED, x_range=(0, 18))
#         andrew = Rectangle(height=3, width=3, color=RED).move_to(LEFT*4.5 + DOWN*2)
#         andrew.z_index = 2
#         andrew_name = Tex("Andrew").scale(1.5).next_to(andrew,LEFT,buff=-0.8).set_color(RED).rotate(np.pi/2)
#         andrew_cost = Tex("$1C=4.5S$").next_to(andrew,RIGHT,buff=-0.8).set_color(RED).rotate(np.pi/2)
#         andrew_group = VGroup(andrew,andrew_name,andrew_cost)
#
#         a_carrots = Rectangle(height=3/2, width=3, color=ORANGE, fill_opacity=1)
#         a_spinach = Rectangle(height=3/2, width=3, color=GREEN, fill_opacity=1)
#         andrew_crops = VGroup(a_carrots,a_spinach.next_to(a_carrots,DOWN,buff=0)).move_to(andrew)
#
#         ppf_guild_graph = axes.plot(PPF_Guild, color=PURPLE, x_range=(0, 63))
#
#         p1m = axes.coords_to_point(22.5, 2.5)
#         p1a = axes.coords_to_point(9, 2)
#         p1g = axes.coords_to_point(31.5, 4.5)
#         dotm = Dot(p1m)
#         dotm.z_index = 2
#         dota = Dot(p1a)
#         dota.z_index = 2
#         dotg = Dot(p1g)
#         dotg.z_index = 2
#
#         guild_name = Tex("Guild PPF").scale(1.2).next_to(axes, UP).set_color(PURPLE)
#
#         spinach_advantage = Tex("Spinach").rotate(np.pi/2).set_color(GREEN).next_to(molly_group,RIGHT)
#         carrot_advantage = Tex("Carrots").rotate(np.pi/2).set_color(ORANGE).next_to(andrew_group,RIGHT)
#
#         """ Setup """
#         self.add(dotm,dota,dotg,spinach_advantage,carrot_advantage)
#         self.add(axes,molly_group,molly_crops,andrew_group,andrew_crops,ppf_molly_graph,ppf_andrew_graph,guild_name,ppf_guild_graph)
#         self.wait()
#
#         """ Show Comparative Advantages """
#
#         molly_ad = axes.coords_to_point(45,0)
#         molly_ad = Dot(molly_ad, radius=0.2, stroke_width=0, fill_opacity=0.3, color='WHITE')
#         molly_ad.z_index = 0
#
#         andrew_ad = axes.coords_to_point(0,4)
#         andrew_ad = Dot(andrew_ad, radius=0.2, stroke_width=0, fill_opacity=0.3, color='WHITE')
#         andrew_ad.z_index = 0
#
#         self.play(FadeIn(molly_ad),FadeIn(andrew_ad))
#         self.wait()
#
#         """ Specialize """
#
#         alpha_pairs = [[1,0],[0,1]]
#         for pair in alpha_pairs:
#             alpha_m = pair[0]
#             alpha_a = pair[1]
#
#             m_carrots_new = Rectangle(height=alpha_m*3, width=3, color=ORANGE, fill_opacity=1)
#             m_spinach_new = Rectangle(height=(1-alpha_m)*3, width=3, color=GREEN, fill_opacity=1)
#             molly_crops_new = VGroup(m_carrots_new,m_spinach_new.next_to(m_carrots_new,DOWN,buff=0)).move_to(molly)
#
#             a_carrots_new = Rectangle(height=alpha_a*3, width=3, color=ORANGE, fill_opacity=1)
#             a_spinach_new = Rectangle(height=(1-alpha_a)*3, width=3, color=GREEN, fill_opacity=1)
#             andrew_crops_new = VGroup(a_carrots_new,a_spinach_new.next_to(a_carrots_new,DOWN,buff=0)).move_to(andrew)
#
#             p2m = axes.coords_to_point(45*(1-alpha_m), 5*alpha_m)
#             p2a = axes.coords_to_point(18*(1-alpha_a), 4*alpha_a)
#             p2g = axes.coords_to_point(45*(1-alpha_m)+18*(1-alpha_a), 5*alpha_m+4*alpha_a)
#
#             self.play(dotm.animate.move_to(p2m),dota.animate.move_to(p2a),dotg.animate.move_to(p2g),
#                       Transform(molly_crops,molly_crops_new),Transform(andrew_crops,andrew_crops_new))
#             self.wait()
#
#         """ Trace The Specialized Guild """
#
#         path = VMobject(color=PINK)
#         path.set_points_as_corners([dotg.get_center(), dotg.get_center()])
#         def update_path(path):
#             previous_path = path.copy()
#             previous_path.add_points_as_corners([dotg.get_center()])
#             path.become(previous_path)
#         path.add_updater(update_path)
#         self.add(path, dotg)
#
#         self.play(ppf_guild_graph.animate.set_opacity(0.1))
#
#         alpha_pairs = [[1,1],[0,1],[0,0]]
#         for pair in alpha_pairs:
#             alpha_m = pair[0]
#             alpha_a = pair[1]
#
#             m_carrots_new = Rectangle(height=alpha_m*3, width=3, color=ORANGE, fill_opacity=1)
#             m_spinach_new = Rectangle(height=(1-alpha_m)*3, width=3, color=GREEN, fill_opacity=1)
#             molly_crops_new = VGroup(m_carrots_new,m_spinach_new.next_to(m_carrots_new,DOWN,buff=0)).move_to(molly)
#
#             a_carrots_new = Rectangle(height=alpha_a*3, width=3, color=ORANGE, fill_opacity=1)
#             a_spinach_new = Rectangle(height=(1-alpha_a)*3, width=3, color=GREEN, fill_opacity=1)
#             andrew_crops_new = VGroup(a_carrots_new,a_spinach_new.next_to(a_carrots_new,DOWN,buff=0)).move_to(andrew)
#
#             p2m = axes.coords_to_point(45*(1-alpha_m), 5*alpha_m)
#             p2a = axes.coords_to_point(18*(1-alpha_a), 4*alpha_a)
#             p2g = axes.coords_to_point(45*(1-alpha_m)+18*(1-alpha_a), 5*alpha_m+4*alpha_a)
#
#             self.play(dotm.animate.move_to(p2m),dota.animate.move_to(p2a),dotg.animate.move_to(p2g),
#                       Transform(molly_crops,molly_crops_new),Transform(andrew_crops,andrew_crops_new))
#             self.wait(1/10)
#
#         """ Show Gains From Specialization """
#
#         a = axes.coords_to_point(63, 0)
#         b = axes.coords_to_point(45, 4)
#         c = axes.coords_to_point(0, 9)
#
#         gains = Polygon(a,b,c, color=PINK, fill_opacity=1)
#         gains.z_index = 0
#         gains_text = Tex('Gains From Specialization').scale(1.2).set_color(PINK).next_to(gains, UP*3).shift(RIGHT/2)
#
#         self.play(FadeOut(guild_name),FadeIn(gains),FadeIn(gains_text))
#         self.wait()
#
#         """ Do More Pairs """
#
#         alpha_pairs = [[0,1],[0.1,1],[0.2,1],[0.3,1],[0.4,1],[0.5,1],[0.6,1],[0.7,1],[0.8,1],[0.9,1],[1,1]] + [[0,0.9],[0,0.8],[0,0.7],[0,0.6],[0,0.5],[0,0.4],[0,0.3],[0,0.2],[0,0.1],[0,0], [0,1]]
#         random.shuffle(alpha_pairs)
#         for pair in alpha_pairs:
#             alpha_m = pair[0]
#             alpha_a = pair[1]
#
#             m_carrots_new = Rectangle(height=alpha_m*3, width=3, color=ORANGE, fill_opacity=1)
#             m_spinach_new = Rectangle(height=(1-alpha_m)*3, width=3, color=GREEN, fill_opacity=1)
#             molly_crops_new = VGroup(m_carrots_new,m_spinach_new.next_to(m_carrots_new,DOWN,buff=0)).move_to(molly)
#
#             a_carrots_new = Rectangle(height=alpha_a*3, width=3, color=ORANGE, fill_opacity=1)
#             a_spinach_new = Rectangle(height=(1-alpha_a)*3, width=3, color=GREEN, fill_opacity=1)
#             andrew_crops_new = VGroup(a_carrots_new,a_spinach_new.next_to(a_carrots_new,DOWN,buff=0)).move_to(andrew)
#
#             p2m = axes.coords_to_point(45*(1-alpha_m), 5*alpha_m)
#             p2a = axes.coords_to_point(18*(1-alpha_a), 4*alpha_a)
#             p2g = axes.coords_to_point(45*(1-alpha_m)+18*(1-alpha_a), 5*alpha_m+4*alpha_a)
#
#             self.play(dotm.animate.move_to(p2m),dota.animate.move_to(p2a),dotg.animate.move_to(p2g),
#                       Transform(molly_crops,molly_crops_new),Transform(andrew_crops,andrew_crops_new))
#             self.wait(1/10)
#
#         self.wait()
# Out:
# Manim Community v0.18.1
# <video src="PartA_E3/jupyter/animation_2@2024-09-04@09-36-15.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Animation 3 | Setup The Questions

# %%
# %%manim animation_3
#
# class animation_3(MovingCameraScene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         PPF_axis = Axes(
#             x_range=[0, 65, 5],
#             x_length = 7,
#             axis_config={"color": WHITE},
#             x_axis_config={
#                 "numbers_to_include": np.arange(0, 65, 15),
#                 "numbers_with_elongated_ticks": np.arange(0, 65, 10),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":GREEN,
#                 },
#             },
#             y_range=[0, 10, 1],
#             y_length = 6,
#             y_axis_config={
#                 "numbers_to_include": np.arange(0, 11, 2),
#                 "numbers_with_elongated_ticks": np.arange(0, 11, 5),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":ORANGE,
#                 }
#             },
#             tips=False,
#         )
#
#         """ Starting Objects """
#
#         axes = PPF_axis.shift(RIGHT*2).scale(0.8)
#
#         ppf_molly_graph = axes.plot(PPF_Molly, color=BLUE, x_range=(0, 45))
#         molly = Rectangle(height=3, width=3, color=BLUE).move_to(LEFT*4.5 + UP*2)
#         molly.z_index = 2
#         molly_name = Tex("Molly").scale(1.5).next_to(molly,LEFT,buff=-1/2).set_color(BLUE).rotate(np.pi/2)
#         molly_cost = Tex("$1C=9S$").next_to(molly,RIGHT,buff=-0.6).set_color(BLUE).rotate(np.pi/2)
#         molly_group = VGroup(molly,molly_name,molly_cost)
#
#         m_carrots = Rectangle(height=3/2, width=3, color=ORANGE, fill_opacity=1)
#         m_spinach = Rectangle(height=3/2, width=3, color=GREEN, fill_opacity=1)
#         molly_crops = VGroup(m_carrots,m_spinach.next_to(m_carrots,DOWN,buff=0)).move_to(molly)
#
#         ppf_andrew_graph = axes.plot(PPF_Andrew, color=RED, x_range=(0, 18))
#         andrew = Rectangle(height=3, width=3, color=RED).move_to(LEFT*4.5 + DOWN*2)
#         andrew.z_index = 2
#         andrew_name = Tex("Andrew").scale(1.5).next_to(andrew,LEFT,buff=-0.8).set_color(RED).rotate(np.pi/2)
#         andrew_cost = Tex("$1C=4.5S$").next_to(andrew,RIGHT,buff=-0.8).set_color(RED).rotate(np.pi/2)
#         andrew_group = VGroup(andrew,andrew_name,andrew_cost)
#
#         a_carrots = Rectangle(height=3/2, width=3, color=ORANGE, fill_opacity=1)
#         a_spinach = Rectangle(height=3/2, width=3, color=GREEN, fill_opacity=1)
#         andrew_crops = VGroup(a_carrots,a_spinach.next_to(a_carrots,DOWN,buff=0)).move_to(andrew)
#
#         p1m = axes.coords_to_point(45, 0)
#         p1a = axes.coords_to_point(0, 4)
#         p1g = axes.coords_to_point(45, 4)
#         dotm = Dot(p1m)
#         dotm.z_index = 2
#         dota = Dot(p1a)
#         dota.z_index = 2
#         dotg = Dot(p1g)
#         dotg.z_index = 2
#
#         spinach_advantage = Tex("Spinach").rotate(np.pi/2).set_color(GREEN).next_to(molly_group,RIGHT)
#         carrot_advantage = Tex("Carrots").rotate(np.pi/2).set_color(ORANGE).next_to(andrew_group,RIGHT)
#
#         """ Setup """
#         self.add(dotm,dota,dotg,spinach_advantage,carrot_advantage)
#         self.add(axes,molly_group,molly_crops,andrew_group,andrew_crops,ppf_molly_graph,ppf_andrew_graph)
#
#         """ Show Comparative Advantages """
#
#         molly_ad = axes.coords_to_point(45,0)
#         molly_ad = Dot(molly_ad, radius=0.2, stroke_width=0, fill_opacity=0.3, color='WHITE')
#         molly_ad.z_index = 0
#
#         andrew_ad = axes.coords_to_point(0,4)
#         andrew_ad = Dot(andrew_ad, radius=0.2, stroke_width=0, fill_opacity=0.3, color='WHITE')
#         andrew_ad.z_index = 0
#
#         self.add(molly_ad, andrew_ad)
#         self.add(dotg)
#
#         """ Show Gains From Specialization """
#
#         a = axes.coords_to_point(63, 0)
#         b = axes.coords_to_point(45, 4)
#         c = axes.coords_to_point(0, 9)
#
#         gains = Polygon(a,b,c, color=PINK, fill_opacity=1)
#         gains.z_index = 0
#         gains_text = Tex('Gains From Specialization').scale(1.2).set_color(PINK).next_to(gains, UP*3).shift(RIGHT/2)
#
#         self.add(gains, gains_text)
#         self.wait()
#
#         """ Setup Questions """
#
#         question1 = Tex('But is a guild necessary?').scale(1.3).set_color(YELLOW).next_to(axes, RIGHT, buff=-1/2)
#         frame_group = VGroup(axes, question1)
#
#         self.play(
#             self.camera.frame.animate.shift(RIGHT*5),
#             FadeOut(molly_group), FadeOut(molly_crops),
#             FadeOut(andrew_group), FadeOut(andrew_crops),
#             FadeOut(spinach_advantage), FadeOut(carrot_advantage),
#             FadeOut(gains_text),
#             FadeIn(question1)
#         )
#
#         self.wait()
#
#         """ Make PPFs """
#
#         PPF_axis_small = Axes(
#             x_range=[0, 65, 5],
#             x_length = 7,
#             axis_config={"color": WHITE},
#             x_axis_config={
#                 "numbers_to_include": np.arange(0, 50, 15),
#                 "numbers_with_elongated_ticks": np.arange(0, 50, 10),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":GREEN,
#                 },
#             },
#             y_range=[0, 6, 1],
#             y_length = 6,
#             y_axis_config={
#                 "numbers_to_include": np.arange(0, 6, 1),
#                 "numbers_with_elongated_ticks": np.arange(0, 6, 5),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":ORANGE,
#                 }
#             },
#             tips=False,
#         )
#
#         axes_m = PPF_axis_small.copy().move_to(axes).shift(RIGHT)
#
#         molly_name_new = Tex("Molly's PPF").scale(1.5).rotate(np.pi/2).set_color(BLUE).next_to(axes_m,LEFT)#.set_x(self.camera.frame.get_left()[0]+2/5)
#
#         new_frame_group = VGroup(axes_m, molly_name, question1)
#
#         new_molly_ad = axes_m.coords_to_point(45,0)
#         new_molly_ad = Dot(new_molly_ad, radius=0.2, stroke_width=0, fill_opacity=0.3, color='WHITE')
#         new_molly_ad.z_index = 0
#
#         new_ppf_molly_graph = axes_m.plot(PPF_Molly, color=BLUE, x_range=(0, 45))
#
#         p1m = axes_m.coords_to_point(45, 0)
#         dotm_new = Dot(p1m)
#         dotm_new.z_index = 2
#
#         self.play(
#             FadeOut(gains), FadeOut(dotg),
#             question1.animate.to_edge(UP).set_x(self.camera.frame.get_center()[0]),
#             Transform(molly_ad, new_molly_ad),
#             Transform(ppf_molly_graph, new_ppf_molly_graph),
#             Transform(dotm, dotm_new),
#             FadeIn(molly_name_new),
#             Transform(axes, axes_m),
#             FadeOut(ppf_andrew_graph, dota, andrew_ad),
#         )
#         self.wait()
#         vertical_axis = NumberLine(
#             x_range=[-5, 5, 1],  # Range from -5 to 5 with step size 1
#             length=4,            # Length of the axis
#             color=WHITE,         # Color of the line
#             include_numbers=False, # Include numbers on the axis
#             include_ticks=False,
#             label_direction=LEFT  # Place numbers to the left of the line
#         ).rotate(PI / 2)  # Rotate by 90 degrees (PI / 2 radians) to make it vertical
#
#         # Correct the orientation of each number label to be horizontal
#         #or number in vertical_axis.numbers:
#             #number.rotate(-PI / 2)  # Rotate labels back to horizontal orientation
#             #number.shift(LEFT * 0.3)
#
#         vertical_carrots = vertical_axis.copy().next_to(axes, RIGHT, buff=2)
#         vertical_spinach = vertical_axis.copy().next_to(vertical_carrots, RIGHT, buff=1/2)
#
#         # Add the vertical axis to the scene
#         self.play(FadeIn(vertical_carrots, vertical_spinach))
#         self.wait(2)
#
#         # Create a point to place on the NumberLine
#         point = Dot(color=RED)
#
#         # Position the point at the number 2 on the NumberLine
#         point_position = vertical_carrots.number_to_point(2)  # Convert number 2 to coordinates
#         point.move_to(point_position)  # Move the point to the calculated position
#
#         # Add the point to the scene
#         self.add(point)
#
#         self.wait(2)
# Out:
# Manim Community v0.18.1
# <video src="PartA_E3/jupyter/animation_3@2024-09-02@17-46-38.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Animation 4 | Trade With Oneself

# %% [markdown]
# - set up exactly like animation 3
# - show the fully specialized harvest and a harvest with one more carrot
# - set up the trade verticals
# - plot molly's opportunity cost on the verticals
# - tie the two dots using always redraw on the verticals to a trade line on molly's ppf
# - compare a trade for one carrot to a self-trade for one carrot
# - show a few different exchange rates
# -

# %%
# %%manim animation_4
#
# PPF_axis = Axes(
#     x_range=[0, 65, 5],
#     x_length = 7,
#     axis_config={"color": WHITE},
#     x_axis_config={
#         "numbers_to_include": np.arange(0, 65, 15),
#         "numbers_with_elongated_ticks": np.arange(0, 65, 10),
#         "decimal_number_config": {
#             "num_decimal_places":0,
#             "color":GREEN,
#         },
#     },
#     y_range=[0, 10, 1],
#     y_length = 6,
#     y_axis_config={
#         "numbers_to_include": np.arange(0, 11, 2),
#         "numbers_with_elongated_ticks": np.arange(0, 11, 5),
#         "decimal_number_config": {
#             "num_decimal_places":0,
#             "color":ORANGE,
#         }
#     },
#     tips=False,
# )
#
# PPF_axis_small = Axes(
#     x_range=[0, 65, 5],
#     x_length = 7,
#     axis_config={"color": WHITE},
#     x_axis_config={
#         "numbers_to_include": np.arange(0, 50, 45),
#         "numbers_with_elongated_ticks": np.arange(0, 50, 10),
#         "decimal_number_config": {
#             "num_decimal_places":0,
#             "color":GREEN,
#         },
#     },
#     y_range=[0, 8, 1],
#     y_length = 6,
#     y_axis_config={
#         "numbers_to_include": np.arange(0, 6, 5),
#         "numbers_with_elongated_ticks": np.arange(0, 6, 5),
#         "decimal_number_config": {
#             "num_decimal_places":0,
#             "color":ORANGE,
#         }
#     },
#     tips=False,
# )
#
# vertical_spinach_axis = NumberLine(
#     x_range=[0, 50, 1],  # Range from -5 to 5 with step size 1
#     length=4,            # Length of the axis
#     color=WHITE,         # Color of the line
#     include_numbers=False, # Include numbers on the axis
#     include_ticks=False,
#     label_direction=LEFT  # Place numbers to the left of the line
# ).rotate(PI / 2)  # Rotate by 90 degrees (PI / 2 radians) to make it vertical
#
# vertical_carrot_axis = NumberLine(
#     x_range=[0, 8, 1],  # Range from -5 to 5 with step size 1
#     length=4,            # Length of the axis
#     color=WHITE,         # Color of the line
#     include_numbers=False, # Include numbers on the axis
#     include_ticks=False,
#     label_direction=LEFT  # Place numbers to the left of the line
# ).rotate(PI / 2)  # Rotate by 90 degrees (PI / 2 radians) to make it vertical
#
#
# class animation_4(MovingCameraScene):
#
#     def construct(self):
#
#         """ Starting Objects """
#
#         axes = PPF_axis.shift(RIGHT*2).scale(0.8)
#         axes_m = PPF_axis_small.copy().move_to(axes).shift(RIGHT)
#
#         question1 = Tex('But is a guild necessary?').scale(1.3).set_color(YELLOW).next_to(axes, RIGHT, buff=-1/2)
#         molly_name = Tex("Molly's PPF").scale(1.5).rotate(np.pi/2).set_color(BLUE).next_to(axes_m,LEFT)
#
#         molly_ad = axes_m.coords_to_point(45,0)
#         molly_ad = Dot(molly_ad, radius=0.2, stroke_width=0, fill_opacity=0.3, color='WHITE')
#         molly_ad.z_index = 0
#
#         ppf_molly_graph = axes_m.plot(PPF_Molly, color=BLUE, x_range=(0, 45))
#
#         p1m = axes_m.coords_to_point(45, 0)
#         dotm = Dot(p1m)
#         dotm.z_index = 2
#
#
#         self.camera.frame.shift(RIGHT*5)
#         quetion1 = question1.to_edge(UP).set_x(self.camera.frame.get_center()[0])
#         self.add(
#             question1, molly_name, molly_ad,
#             ppf_molly_graph, dotm, axes_m
#         )
#
#         p1m_self = axes_m.coords_to_point(45-27, 3)
#         dotm_self = Dot(p1m_self)
#
#         # Create a CurvedArrow
#         curved_arrow = CurvedArrow(p1m, p1m_self, color=RED, angle=PI / 4).shift(RIGHT/5+UP/5)
#
#         p2m = axes_m.coords_to_point(45, 0)
#         dot2m = Dot(p1m)
#         dotm.z_index = 2
#
#         m_value = ValueTracker(45)
#
#         def Move_M():
#             x = m_value.get_value()
#             x_int = axes_m.coords_to_point(x,0)
#             x_label = DecimalNumber(num_decimal_places=1).set_color(GREEN).scale(0.8).next_to(x_int,DOWN,buff=1/4).set_value(x)
#             y = PPF_Molly(x)
#             y_int = axes_m.coords_to_point(0,y)
#             y_label = DecimalNumber(num_decimal_places=1).set_color(ORANGE).scale(0.8).next_to(y_int,LEFT,buff=0).set_value(y).rotate(np.pi/2)
#             p = axes_m.coords_to_point(x,y)
#             dot = Dot(p).set_color(WHITE)
#             dot.z_index = 2
#             vline = DashedLine(x_int,p).set_color(GREY)
#             hline = DashedLine(y_int,p).set_color(GREY)
#
#             y_intercept = axes_m.coords_to_point(0,0)
#
#             carrot_line = Line(start=p2m, end=x_int, color=GREEN, stroke_width=8)
#             spinach_line = Line(start=y_intercept, end=y_int, color=ORANGE, stroke_width=8)
#
#             return VGroup(dot,vline,hline,x_label,y_label,carrot_line,spinach_line)#,exchange_spinach,exchange_carrot)
#
#         self.remove(dotm)
#         dotm = always_redraw(Move_M)
#         self.add(dotm)
#
#         """ Op Cost Math 1 """
#
#         self.play(Create(curved_arrow), m_value.animate.set_value(45-27),run_time=3)
#
#         x = m_value.get_value()
#         y = PPF_Molly(x)
#         y_ex_p = axes_m.coords_to_point(0,y/2)
#         x_ex_p = axes_m.coords_to_point((45+x)/2,0)
#
#         exchange_carrot = Tex('{{3}} {{C}}').set_color(ORANGE).scale(0.8).next_to(y_ex_p,RIGHT,buff=1/4).set_value(y)
#         exchange_spinach = Tex('{{27}} {{S}}').set_color(GREEN).scale(0.8).next_to(x_ex_p,UP,buff=1/4).set_value(45-x)
#
#         self.play(FadeIn(exchange_spinach, exchange_carrot))
#
#         self.wait(1/2)
#
#         OR = Tex("or").next_to(axes_m,RIGHT,buff=2).scale(1.5)
#         equal = Tex("=").next_to(axes_m,RIGHT,buff=2).scale(1.5)
#
#         self.play(FadeIn(OR),exchange_spinach.animate.next_to(OR,RIGHT,buff=1).scale(1.5/0.8),exchange_carrot.animate.next_to(OR,LEFT,buff=1).scale(1.5/0.8))
#         self.wait(1/2)
#         self.play(Transform(OR,equal))
#         self.wait(1/2)
#
#         exchange_carrot_new = Tex(r"$\frac{3}{3}$ {{C}}").scale(1.5).next_to(OR,LEFT,buff=1).set_color_by_tex_to_color_map({
#                 "C": ORANGE,
#             })
#         exchange_spinach_new = Tex(r"{{$\frac{27}{3}$}} {{S}}").scale(1.5).next_to(OR,RIGHT,buff=1).set_color_by_tex_to_color_map({
#                 "S": GREEN,
#             })
#         self.play(Transform(exchange_carrot[0],exchange_carrot_new[0]),Transform(exchange_spinach[0],exchange_spinach_new[0]))
#         self.wait(1/2)
#
#         exchange_carrot_new = Tex('{{1}} {{C}}').scale(1.5).next_to(OR,LEFT,buff=1).set_color_by_tex_to_color_map({
#                 "C": ORANGE,
#             })
#         exchange_spinach_new = Tex('{{9}} {{S}}').scale(1.5).next_to(OR,RIGHT,buff=1).set_color_by_tex_to_color_map({
#                 "S": GREEN,
#             })
#         self.play(Transform(exchange_carrot[0],exchange_carrot_new[0]),Transform(exchange_spinach[0],exchange_spinach_new[0]))
#         self.wait(1/2)
#
#         self.play(FadeOut(exchange_spinach, curved_arrow, OR, exchange_carrot))
#
#         self.wait(1/2)
#
#         """ Op Cost Math 2 """
#
#         p1m_self = axes_m.coords_to_point(45-18, 2)
#         dotm_self = Dot(p1m_self)
#
#         # Create a CurvedArrow
#         curved_arrow = CurvedArrow(p1m, p1m_self, color=RED, angle=PI / 4).shift(RIGHT/5+UP/5)
#
#         self.play(Create(curved_arrow), m_value.animate.set_value(45-18),run_time=3)
#
#         x = m_value.get_value()
#         y = PPF_Molly(x)
#         y_ex_p = axes_m.coords_to_point(0,y/2)
#         x_ex_p = axes_m.coords_to_point((45+x)/2,0)
#
#         exchange_carrot = Tex('{{2}} {{C}}').set_color(ORANGE).scale(0.8).next_to(y_ex_p,RIGHT,buff=1/4).set_value(y)
#         exchange_spinach = Tex('{{18}} {{S}}').set_color(GREEN).scale(0.8).next_to(x_ex_p,UP,buff=1/4).set_value(45-x)
#
#         self.play(FadeIn(exchange_spinach, exchange_carrot))
#
#         self.wait(1/2)
#
#         OR = Tex("or").next_to(axes_m,RIGHT,buff=2).scale(1.5)
#         equal = Tex("=").next_to(axes_m,RIGHT,buff=2).scale(1.5)
#
#         self.play(FadeIn(OR),exchange_spinach.animate.next_to(OR,RIGHT,buff=1).scale(1.5/0.8),exchange_carrot.animate.next_to(OR,LEFT,buff=1).scale(1.5/0.8))
#         self.wait(1/2)
#         self.play(Transform(OR,equal))
#         self.wait(1/2)
#
#         exchange_carrot_new = Tex(r"$\frac{2}{2}$ {{C}}").scale(1.5).next_to(OR,LEFT,buff=1).set_color_by_tex_to_color_map({
#                 "C": ORANGE,
#             })
#         exchange_spinach_new = Tex(r"{{$\frac{18}{2}$}} {{S}}").scale(1.5).next_to(OR,RIGHT,buff=1).set_color_by_tex_to_color_map({
#                 "S": GREEN,
#             })
#         self.play(Transform(exchange_carrot[0],exchange_carrot_new[0]),Transform(exchange_spinach[0],exchange_spinach_new[0]))
#         self.wait(1/2)
#
#         exchange_carrot_new = Tex('{{1}} {{C}}').scale(1.5).next_to(OR,LEFT,buff=1).set_color_by_tex_to_color_map({
#                 "C": ORANGE,
#             })
#         exchange_spinach_new = Tex('{{9}} {{S}}').scale(1.5).next_to(OR,RIGHT,buff=1).set_color_by_tex_to_color_map({
#                 "S": GREEN,
#             })
#         self.play(Transform(exchange_carrot[0],exchange_carrot_new[0]),Transform(exchange_spinach[0],exchange_spinach_new[0]))
#         self.wait(1/2)
#
#         molly_exchange = VGroup(exchange_spinach, OR, exchange_carrot)
#         molly_exchange_new = Tex('1 C = 9 S').set_color(BLUE).next_to(axes_m,UP,buff=-1)
#
#         self.play(Transform(molly_exchange, molly_exchange_new))
#         self.wait(1/2)
#
#         """ Trade Deal: Offer Molly 3 instead of 2 """
#
#         c_X = ValueTracker(3)
#         s_X = ValueTracker(27)
#
#         def Move_MX():
#             x = s_X.get_value()
#             x_int = axes_m.coords_to_point(x,0)
#
#             y = c_X.get_value()
#             y_int = axes_m.coords_to_point(0,y)
#
#             p = axes_m.coords_to_point(x,y)
#             dot = Dot(p).set_color(PURPLE)
#             dot.z_index = 2
#             vline = DashedLine(x_int,p).set_color(GREY)
#             hline = DashedLine(y_int,p).set_color(GREY)
#
#             start = axes_m.coords_to_point(0.4,0)
#             end = axes_m.coords_to_point(0.4,y)
#             carrot_line = Line(start=start, end=end, color=PINK, stroke_width=8)
#             y_label = DecimalNumber(num_decimal_places=1).set_color(PURPLE).scale(0.8).next_to(y_int,RIGHT,buff=0).set_value(y).rotate(np.pi/2)
#
#             start = axes_m.coords_to_point(45,0.4/9)
#             end = axes_m.coords_to_point(x,0.4/9)
#             spinach_line = Line(start=start, end=end, color=PURPLE, stroke_width=8)
#             x_label = DecimalNumber(num_decimal_places=1).set_color(PURPLE).scale(0.8).next_to(x_int,UP,buff=1/4).set_value(x)
#
#             return VGroup(dot,vline,hline,y_label,carrot_line,spinach_line,x_label)#,exchange_spinach,exchange_carrot)
#
#         dotmx = always_redraw(Move_MX)
#
#         exchange_carrot = Tex('{{3}} {{C}}').set_color(PURPLE).scale(0.8).next_to(dotmx[4],RIGHT,buff=0)
#         exchange_spinach = Tex('{{18}} {{S}}').set_color(PURPLE).scale(0.8).next_to(dotmx[5],UP,buff=0)
#
#         self.play(FadeIn(dotmx), FadeIn(exchange_carrot, exchange_spinach), FadeOut(curved_arrow))
#
#         self.wait(1/2)
#
#         OR = Tex("or").next_to(axes_m,RIGHT,buff=2).scale(1.5)
#         equal = Tex("=").next_to(axes_m,RIGHT,buff=2).scale(1.5)
#
#         self.play(FadeIn(OR),exchange_spinach.animate.next_to(OR,RIGHT,buff=1).scale(1.5/0.8),exchange_carrot.animate.next_to(OR,LEFT,buff=1).scale(1.5/0.8))
#         self.wait(1/2)
#         self.play(Transform(OR,equal))
#         self.wait(1/2)
#
#         exchange_carrot_new = Tex(r"$\frac{3}{3}$ {{C}}").scale(1.5).next_to(OR,LEFT,buff=1).set_color_by_tex_to_color_map({
#                 "C": PURPLE,
#             })
#         exchange_spinach_new = Tex(r"{{$\frac{18}{3}$}} {{S}}").scale(1.5).next_to(OR,RIGHT,buff=1).set_color_by_tex_to_color_map({
#                 "S": PURPLE,
#             })
#         self.play(Transform(exchange_carrot[0],exchange_carrot_new[0]),Transform(exchange_spinach[0],exchange_spinach_new[0]))
#         self.wait(1/2)
#
#         exchange_carrot_new = Tex('{{1}} {{C}}').scale(1.5).next_to(OR,LEFT,buff=1).set_color_by_tex_to_color_map({
#                 "C": PURPLE,
#             })
#         exchange_spinach_new = Tex('{{6}} {{S}}').scale(1.5).next_to(OR,RIGHT,buff=1).set_color_by_tex_to_color_map({
#                 "S": PURPLE,
#             })
#         self.play(Transform(exchange_carrot[0],exchange_carrot_new[0]),Transform(exchange_spinach[0],exchange_spinach_new[0]))
#         self.wait(1/2)
#
#         exchange_rate = VGroup(exchange_spinach, OR, exchange_carrot)
#
#         exchange_rate_new = Tex('1 C = {{6}} S').set_color(PURPLE)
#         exchange_rate_new.next_to(molly_exchange, RIGHT, buff=2)
#
#         self.play(Transform(exchange_rate, exchange_rate_new))
#         self.wait(1/2)
#
#         e_box = SurroundingRectangle(exchange_rate, buff=1/4)
#         self.play(Create(e_box))
#
#         m_box = SurroundingRectangle(molly_exchange, buff=1/4)
#         self.play(Create(m_box))
#
#         self.wait(1/2)
#
#         self.play(FadeOut(e_box),FadeOut(m_box))
#
#         #trade_point_new = axes_m.coords_to_point(, )
#         #trade_dot_new = Dot(trade_point_new).set_color(PURPLE)
#         #trade_dot_new.z_index = 3
#
#         self.wait(1/2)
#
#         self.play(
#             s_X.animate.set_value(45-27),
#             c_X.animate.set_value(27/6),
#             m_value.animate.set_value(45-27)
#         )
#
#         self.wait(1/2)
#         # Then show the trade line when it's good like this
#
#         alpha_m = 0
#         alpha_a = 1
#         c_x = ValueTracker(1)
#         s_x = ValueTracker(6)
#         def trade_molly(s):
#             x = s - (1-alpha_m)*45
#             return alpha_m*5 - x*c_x.get_value()/s_x.get_value()
#
#         trade_line = DashedVMobject(axes_m.plot(trade_molly, color=PINK, x_range=(0, 45)))
#
#         self.play(FadeIn(trade_line))
#
#         self.wait(1/2)
#
#         """ Then change the exchange rate 1 for 4 """
#
#         # exchange rate label
#         exchange_rate_new = Tex('1 C = {{4}} S').set_color(PURPLE).next_to(molly_exchange, RIGHT, buff=2)
#
#         # exchange rate line
#         s_x.set_value(4)
#
#         trade_line_new = DashedVMobject(axes_m.plot(trade_molly, color=PINK, x_range=(0, 45)))
#
#         self.play(
#             c_X.animate.set_value(27/4),
#             Transform(exchange_rate,exchange_rate_new),
#             Transform(trade_line,trade_line_new)
#         )
#         self.wait(1/2)
#
#         self.play(
#             c_X.animate.set_value((45-24)/4),
#             s_X.animate.set_value(24)
#         )
#         self.wait(1/2)
# Out:
# Manim Community v0.18.1
# <video src="PartA_E3/jupyter/animation_4@2024-09-04@08-56-23.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim animation_5
#
# PPF_axis = Axes(
#     x_range=[0, 65, 5],
#     x_length = 7,
#     axis_config={"color": WHITE},
#     x_axis_config={
#         "numbers_to_include": np.arange(0, 65, 15),
#         "numbers_with_elongated_ticks": np.arange(0, 65, 10),
#         "decimal_number_config": {
#             "num_decimal_places":0,
#             "color":GREEN,
#         },
#     },
#     y_range=[0, 10, 1],
#     y_length = 6,
#     y_axis_config={
#         "numbers_to_include": np.arange(0, 11, 2),
#         "numbers_with_elongated_ticks": np.arange(0, 11, 5),
#         "decimal_number_config": {
#             "num_decimal_places":0,
#             "color":ORANGE,
#         }
#     },
#     tips=False,
# )
#
# PPF_axis_small = Axes(
#     x_range=[0, 65, 5],
#     x_length = 7,
#     axis_config={"color": WHITE},
#     x_axis_config={
#         "numbers_to_include": np.arange(0, 50, 45),
#         "numbers_with_elongated_ticks": np.arange(0, 50, 10),
#         "decimal_number_config": {
#             "num_decimal_places":0,
#             "color":GREEN,
#         },
#     },
#     y_range=[0, 8, 1],
#     y_length = 6,
#     y_axis_config={
#         "numbers_to_include": np.arange(0, 6, 5),
#         "numbers_with_elongated_ticks": np.arange(0, 6, 5),
#         "decimal_number_config": {
#             "num_decimal_places":0,
#             "color":ORANGE,
#         }
#     },
#     tips=False,
# )
#
# vertical_spinach_axis = NumberLine(
#     x_range=[0, 50, 1],  # Range from -5 to 5 with step size 1
#     length=4,            # Length of the axis
#     color=WHITE,         # Color of the line
#     include_numbers=False, # Include numbers on the axis
#     include_ticks=False,
#     label_direction=LEFT  # Place numbers to the left of the line
# ).rotate(PI / 2)  # Rotate by 90 degrees (PI / 2 radians) to make it vertical
#
# vertical_carrot_axis = NumberLine(
#     x_range=[0, 8, 1],  # Range from -5 to 5 with step size 1
#     length=4,            # Length of the axis
#     color=WHITE,         # Color of the line
#     include_numbers=False, # Include numbers on the axis
#     include_ticks=False,
#     label_direction=LEFT  # Place numbers to the left of the line
# ).rotate(PI / 2)  # Rotate by 90 degrees (PI / 2 radians) to make it vertical
#
#
# class animation_5(MovingCameraScene):
#
#     def construct(self):
#
#         self.camera.frame.shift(RIGHT*5)
#
#         """ Starting Axes """
#
#         axes = PPF_axis.shift(RIGHT*2).scale(0.8)
#         axes_m = PPF_axis_small.copy().move_to(axes).shift(RIGHT)
#
#         vertical_spinach = vertical_spinach_axis.copy().next_to(axes_m, RIGHT, buff=2)
#         vertical_carrots = vertical_carrot_axis.copy().next_to(vertical_spinach, RIGHT, buff=1/2)
#
#         axes_a = PPF_axis_small.copy().next_to(vertical_carrots, buff=1).shift(RIGHT)
#
#         """ Starting Text """
#
#         question1 = Tex('But is a guild necessary?').scale(1.3).set_color(YELLOW).next_to(axes, RIGHT, buff=-1/2)
#         quetion1 = question1.to_edge(UP).set_x(self.camera.frame.get_center()[0])
#
#         molly_name = Tex("Molly's PPF").scale(1.5).rotate(np.pi/2).set_color(BLUE).next_to(axes_m,LEFT)
#         molly_exchange = Tex('1 C = 9 S').set_color(BLUE).rotate(np.pi/2).next_to(axes_m,RIGHT,buff=1/2)
#
#         """ Starting Graph Objects """
#
#         molly_ad = axes_m.coords_to_point(45,0)
#         molly_ad = Dot(molly_ad, radius=0.2, stroke_width=0, fill_opacity=0.3, color='WHITE')
#         molly_ad.z_index = 0
#
#         ppf_molly_graph = axes_m.plot(PPF_Molly, color=BLUE, x_range=(0, 45))
#         ppf_andrew_graph = axes_a.plot(PPF_Andrew, color=RED, x_range=(0, 18))
#
#
#         alpha_m = 0
#         alpha_a = 1
#         c_x = ValueTracker(27/4)
#         s_x = ValueTracker(27)
#         m_value = ValueTracker(45-27)
#
#         def Move_X():
#             cx = c_x.get_value()
#             sx = s_x.get_value()
#
#             c_t_point = Dot(color=PURPLE)
#             c_t_point_position = vertical_carrots.number_to_point(cx)
#             c_t_point.move_to(c_t_point_position)
#             c_t_point.z_index = 3
#
#             s_t_point = Dot(color=PURPLE)
#             s_t_point_position = vertical_spinach.number_to_point(sx)
#             s_t_point.move_to(s_t_point_position)
#             s_t_point.z_index = 3
#
#             trade_point = axes_m.coords_to_point(45-sx, sx/4)
#             trade_dot = Dot(trade_point).set_color(PURPLE)
#             trade_dot.z_index = 3
#
#             first = Tex("1 C = ")
#             second = DecimalNumber(sx/cx, num_decimal_places=0)
#             third = Tex(" S")
#             exchange_rate = VGroup(first,second,third).arrange(RIGHT).set_color(PURPLE)
#             exchange_rate = exchange_rate.next_to(VGroup(vertical_spinach, vertical_carrots), DOWN, buff=1/2)
#
#             def trade_molly(s):
#                 x = s - (1-alpha_m)*45
#                 return alpha_m * 5 - x * cx/sx
#
#             trade_line_m = DashedVMobject(axes_m.plot(trade_molly, color=PINK, x_range=(0, 45)))
#
#             def trade_andrew(s):
#                 x = s - (1-alpha_a)*18
#                 return alpha_a*4 - x*cx/sx
#
#             trade_line_a = DashedVMobject(axes_a.plot(trade_andrew, color=PINK, x_range=(0, 45)))
#
#             return VGroup(
#                 c_t_point, s_t_point, trade_dot,
#                 trade_line_m, exchange_rate,
#                 trade_line_a
#             )
#         dotx = always_redraw(Move_X)
#
#         def Move_M():
#             p1m_self = axes_m.coords_to_point(45-27, 3)
#             dotm_self = Dot(p1m_self)
#
#             p1m = axes_m.coords_to_point(45, 0)
#             dotm = Dot(p1m)
#             dotm.z_index = 2
#
#             p2m = axes_m.coords_to_point(45, 0)
#             dot2m = Dot(p1m)
#             dotm.z_index = 2
#
#             x = m_value.get_value()
#             x_int = axes_m.coords_to_point(x,0)
#             x_label = DecimalNumber(num_decimal_places=1).set_color(GREEN).scale(0.8).next_to(x_int,DOWN,buff=1/4).set_value(x)
#
#             y = PPF_Molly(x)
#             y_int = axes_m.coords_to_point(0,y)
#             y_label = DecimalNumber(num_decimal_places=1).set_color(ORANGE).scale(0.8).next_to(y_int,LEFT,buff=0).set_value(y).rotate(np.pi/2)
#
#             p = axes_m.coords_to_point(x,y)
#             dot = Dot(p).set_color(WHITE)
#             dot.z_index = 2
#
#             vline = DashedLine(x_int,p).set_color(GREY)
#             hline = DashedLine(y_int,p).set_color(GREY)
#
#             y_intercept = axes_m.coords_to_point(0,0)
#
#             carrot_line = Line(start=p2m, end=x_int, color=GREEN, stroke_width=8)
#             spinach_line = Line(start=y_intercept, end=y_int, color=ORANGE, stroke_width=8)
#
#             start_point = vertical_carrots.n2p(0)
#             end_point = vertical_carrots.n2p(y)
#             c_line = Line(start=start_point, end=end_point, color=ORANGE, stroke_width=8)
#             c_line.z_index = 1
#
#             c_label = DecimalNumber(num_decimal_places=1).set_value(y).scale(0.8).set_color(ORANGE)
#             c_label.next_to(end_point, RIGHT)
#
#             start_point = vertical_spinach.n2p(0)
#             end_point = vertical_spinach.n2p(45-x)
#             s_line = Line(start=start_point, end=end_point, color=GREEN, stroke_width=8)
#             s_line.z_index = 1
#
#             s_label = DecimalNumber(num_decimal_places=1).set_value(45-x).scale(0.8).set_color(GREEN)
#             s_label.next_to(end_point, LEFT)
#
#             return VGroup(
#                 dot,vline,hline,x_label,y_label,carrot_line,spinach_line,
#                 c_line,c_label, s_line, s_label
#                          )
#
#         dotm = always_redraw(Move_M)
#
#         def Move_A():
#             p1a_self = axes_a.coords_to_point(45-27, 3)
#             dota_self = Dot(p1a_self)
#
#             p1a = axes_a.coords_to_point(45, 0)
#             dota = Dot(p1a)
#             dota.z_index = 2
#
#             p2a = axes_a.coords_to_point(45, 0)
#             dot2a = Dot(p1a)
#             dota.z_index = 2
#
#             x = m_value.get_value()
#             x_int = axes_a.coords_to_point(x,0)
#             x_label = DecimalNumber(num_decimal_places=1).set_color(GREEN).scale(0.8).next_to(x_int,DOWN,buff=1/4).set_value(x)
#
#             y = PPF_Andrew(x)
#             y_int = axes_a.coords_to_point(0,y)
#             y_label = DecimalNumber(num_decimal_places=1).set_color(ORANGE).scale(0.8).next_to(y_int,LEFT,buff=0).set_value(y).rotate(np.pi/2)
#
#             p = axes_a.coords_to_point(x,y)
#             dot = Dot(p).set_color(WHITE)
#             dot.z_index = 2
#
#             vline = DashedLine(x_int,p).set_color(GREY)
#             hline = DashedLine(y_int,p).set_color(GREY)
#
#             y_intercept = axes_a.coords_to_point(0,0)
#
#             carrot_line = Line(start=p2a, end=x_int, color=GREEN, stroke_width=8)
#             spinach_line = Line(start=y_intercept, end=y_int, color=ORANGE, stroke_width=8)
#
#             start_point = vertical_carrots.n2p(0)
#             end_point = vertical_carrots.n2p(y)
#             c_line = Line(start=start_point, end=end_point, color=ORANGE, stroke_width=8)
#             c_line.z_index = 1
#
#             c_label = DecimalNumber(num_decimal_places=1).set_value(y).scale(0.8).set_color(ORANGE)
#             c_label.next_to(end_point, RIGHT)
#
#             start_point = vertical_spinach.n2p(0)
#             end_point = vertical_spinach.n2p(45-x)
#             s_line = Line(start=start_point, end=end_point, color=GREEN, stroke_width=8)
#             s_line.z_index = 1
#
#             s_label = DecimalNumber(num_decimal_places=1).set_value(45-x).scale(0.8).set_color(GREEN)
#             s_label.next_to(end_point, LEFT)
#
#             return VGroup(
#                 dot,vline,hline,x_label,y_label,carrot_line,spinach_line,
#                 c_line,c_label, s_line, s_label
#                          )
#
#         dota = always_redraw(Move_A)
#
#         """ Add Objects """
#
#         self.add(
#             question1,
#             molly_name,
#             molly_ad,
#             ppf_molly_graph,
#             dotm,
#             dotx,
#             axes_m,
#             dotm,
#             molly_exchange,
#             vertical_carrots,
#             vertical_spinach,
#             #c_t_point,
#             #s_t_point,
#             #trade_dot,
#             #exchange_rate,
#             #trade_line,
#         )
#
#         self.play(
#             FadeIn(axes_a, dota, ppf_andrew_graph),
#             #self.camera.frame.animate,
#             self.camera.frame.animate.set(width=23).shift(RIGHT*4+UP),
#             question1.animate.shift(RIGHT*3.5+UP*3).scale(1.5)
#         )
#         self.wait()
#
#         #self.play(m_value.animate.set_value(0))
#
# # the colored lines on the ppf graph are enough
# # take them off the vertical lines and use the vertical lines only later
# # how to show trade then?
# # show a purple line on the ppf graph, like the orange and green
# # do the op cost math thing with trade
# # then put the exchange rate right below the question
#
# # show the trade vertical lines with color and a purple dot
# # show the purple line on the ppf graphs
# Out:
# Manim Community v0.18.1
# <video src="PartA_E3/jupyter/animation_5@2024-09-03@21-14-38.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim animation_5
#
# class animation_5(MovingCameraScene):
#
#     def construct(self):
#         """ Make PPFs """
#
#         PPF_axis_small = Axes(
#             x_range=[0, 65, 5],
#             x_length = 7,
#             axis_config={"color": WHITE},
#             x_axis_config={
#                 "numbers_to_include": np.arange(0, 50, 45),
#                 "numbers_with_elongated_ticks": np.arange(0, 50, 10),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":GREEN,
#                 },
#             },
#             y_range=[0, 6, 1],
#             y_length = 6,
#             y_axis_config={
#                 "numbers_to_include": np.arange(0, 6, 5),
#                 "numbers_with_elongated_ticks": np.arange(0, 6, 5),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":ORANGE,
#                 }
#             },
#             tips=False,
#         )
#
#         axes_a = PPF_axis_small.copy()
#         ppf_andrew_graph = axes_a.plot(PPF_Andrew, color=RED, x_range=(0, 18))
#         andrew_name = Tex("Andrew").scale(1.2).next_to(axes_a,UP,buff=1/2).set_color(RED)
#
#         axes_m = PPF_axis_small.copy().next_to(axes_a, LEFT*2)
#         ppf_molly_graph = axes_m.plot(PPF_Molly, color=BLUE, x_range=(0, 45))
#         molly_name = Tex("Molly").scale(1.2).next_to(axes_m,UP,buff=1/2).set_color(BLUE)
#
#         molly_ad = axes_m.coords_to_point(45,0)
#         molly_ad = Dot(molly_ad, radius=0.2, stroke_width=0, fill_opacity=0.3, color='WHITE')
#         molly_ad.z_index = 0
#
#         andrew_ad = axes_a.coords_to_point(0,4)
#         andrew_ad = Dot(andrew_ad, radius=0.2, stroke_width=0, fill_opacity=0.3, color='WHITE')
#         andrew_ad.z_index = 0
#
#         p1m = axes_m.coords_to_point(45, 0)
#         p1a = axes_a.coords_to_point(0, 4)
#
#         dotm = Dot(p1m)
#         dotm.z_index = 2
#         dota = Dot(p1a)
#         dota.z_index = 2
#
#         frame_group = VGroup(
#             axes_m, dotm, molly_name, ppf_molly_graph, molly_ad,
#             axes_a, dota, andrew_name, ppf_andrew_graph, andrew_ad,
#         )
#         title = Tex('But is a guild necessary?').scale(1.3).set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#
#         self.add(frame_group, title)
#         self.camera.frame.move_to(frame_group).set(width=frame_group.width*1.3),
#
#         self.wait()
#
#         """ Self Trade """
#
#         m_value = ValueTracker(45)
#         a_value = ValueTracker(0)
#
#         def Move_M():
#             x = m_value.get_value()
#             x_int = axes_m.coords_to_point(x,0)
#             x_label = DecimalNumber(num_decimal_places=2).set_color(GREEN).scale(0.8).next_to(x_int,DOWN,buff=2/3).set_value(x)
#             y = PPF_Molly(x)
#             y_int = axes_m.coords_to_point(0,y)
#             y_label = DecimalNumber(num_decimal_places=2).set_color(ORANGE).scale(0.8).next_to(y_int,LEFT).set_value(y)
#             p = axes_m.coords_to_point(x,y)
#             dot = Dot(p).set_color(WHITE)
#             dot.z_index = 2
#             vline = DashedLine(x_int,p).set_color(GREY)
#             hline = DashedLine(y_int,p).set_color(GREY)
#
#             p2m = axes_m.coords_to_point(45, 0)
#             y_intercept = axes_m.coords_to_point(0,0)
#
#             carrot_line = Line(start=p2m, end=x_int, color=GREEN, stroke_width=8)
#             spinach_line = Line(start=y_intercept, end=y_int, color=ORANGE, stroke_width=8)
#
#
#             return VGroup(dot,vline,hline,x_label,y_label, carrot_line, spinach_line)
#
#         def Move_A():
#             x = a_value.get_value()
#             x_int = axes_a.coords_to_point(x,0)
#             x_label = DecimalNumber(num_decimal_places=2).set_color(GREEN).scale(0.8).next_to(x_int,DOWN,buff=2/3).set_value(x)
#             y = PPF_Andrew(x)
#             y_int = axes_a.coords_to_point(0,y)
#             y_label = DecimalNumber(num_decimal_places=2).set_color(ORANGE).scale(0.8).next_to(y_int,LEFT).set_value(y)
#             p = axes_a.coords_to_point(x,y)
#             dot = Dot(p).set_color(WHITE)
#             dot.z_index = 2
#             vline = DashedLine(x_int,p).set_color(GREY)
#             hline = DashedLine(y_int,p).set_color(GREY)
#
#             p2a = axes_a.coords_to_point(0, 0)
#             y_intercept = axes_a.coords_to_point(0,4)
#
#             spinach_line = Line(start=p2a, end=x_int, color=GREEN, stroke_width=8)
#             carrot_line = Line(start=y_intercept, end=y_int, color=ORANGE, stroke_width=8)
#
#             return VGroup(dot,vline,hline,x_label,y_label, carrot_line, spinach_line)
#
#         self.remove(dotm)
#         dotm = always_redraw(Move_M)
#         self.add(dotm)
#
#         self.play(m_value.animate.set_value(36),run_time=3)
#         self.wait()
#
#         molly_cost = Tex("1C"," for ","9S").set_color(BLUE).next_to(molly_name,DOWN)
#         self.play(FadeIn(molly_cost))
#         self.wait()
#
#         m_box = SurroundingRectangle(molly_cost[2], buff=1/4)
#         self.play(FadeIn(m_box))
#         self.wait()
#
#         self.play(m_value.animate.set_value(45),run_time=3)
#         new_title = Tex('Molly benefits if she trades away less than 9S.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(Transform(title, new_title))
#         self.wait()
#
#         self.remove(dota)
#         dota = always_redraw(Move_A)
#         self.add(dota)
#         self.remove(dotm)
#
#         self.play(a_value.animate.set_value(9/2),run_time=3)
#         self.wait()
#
#         andrew_cost = Tex("1C"," for ","4.5S").set_color(RED).next_to(andrew_name,DOWN)
#         self.play(FadeIn(andrew_cost))
#         self.wait()
#
#         a_box = SurroundingRectangle(andrew_cost[2], buff=1/4)
#         self.play(FadeIn(a_box))
#         self.wait()
#
#         new_title = Tex('Andrew benefits if he trades for more than 4.5S.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(Transform(title, new_title))
#         self.wait()
#
#         self.play(a_value.animate.set_value(0),run_time=3)
#         self.wait()
#
#         self.remove(dota)
#
#         """ Exchange Rate """
#
#         c_x = ValueTracker(1)
#         s_x = ValueTracker(6)
#         def Exchange():
#             c = c_x.get_value()
#             c_value = DecimalNumber(num_decimal_places=0).set_value(c)
#             s = s_x.get_value()
#             s_value = DecimalNumber(num_decimal_places=1).set_value(s)
#
#             return Tex(f"{int(c)} C"," for ",f"{round(s,1)} S").set_color(PINK).scale(1.2).next_to(frame_group,UP, buff=-1/4)
#         exchange = always_redraw(Exchange)
#         self.play(FadeIn(exchange))
#         self.wait()
#
#         e_box = SurroundingRectangle(exchange[2], buff=1/4)
#         self.play(FadeIn(e_box))
#         self.wait()
#
#         alpha_m = 0
#         alpha_a = 1
#
#         def trade_molly(s):
#             x = s - (1-alpha_m)*45
#             return alpha_m*5 - x*c_x.get_value()/s_x.get_value()
#
#         def Trade_M():
#             trade_line = DashedVMobject(axes_m.plot(trade_molly, color=PINK, x_range=(0, 50)))
#
#             x = m_value.get_value()
#             x_int = axes_m.coords_to_point(x,0)
#             y = trade_molly(x)
#             y_int = axes_m.coords_to_point(0,y)
#             y_label = DecimalNumber(num_decimal_places=1).set_color(PURPLE).scale(0.8).next_to(y_int,LEFT,buff=1).set_value(y)
#             p = axes_m.coords_to_point(x,y)
#             dot = Dot(p).set_color(PURPLE)
#             dot.z_index = 2
#             vline = DashedLine(x_int,p).set_color(GREY)
#             hline = DashedLine(y_int,p).set_color(GREY)
#
#             start = axes_m.coords_to_point(0.4,0)
#             end = axes_m.coords_to_point(0.4,y)
#             carrot_line = Line(start=start, end=end, color=PINK, stroke_width=8)
#             #y_label = DecimalNumber(num_decimal_places=1).set_color(PURPLE).scale(0.8).next_to(y_int,RIGHT,buff=0).set_value(y).rotate(np.pi/2)
#
#             start = axes_m.coords_to_point(45,0.4/9)
#             end = axes_m.coords_to_point(x,0.4/9)
#             spinach_line = Line(start=start, end=end, color=PURPLE, stroke_width=8)
#             x_label = DecimalNumber(num_decimal_places=1).set_color(PURPLE).scale(0.8).next_to(x_int,UP,buff=1/4).set_value(x)
#
#             return VGroup(trade_line,dot,vline,hline,y_label,x_label,carrot_line,spinach_line)
#
#         trade_m = always_redraw(Trade_M)
#
#
#         def trade_andrew(s):
#             x = s - (1-alpha_a)*18
#             return alpha_a*4 - x*c_x.get_value()/s_x.get_value()
#
#         def Trade_A():
#             trade_line = DashedVMobject(axes_a.plot(trade_andrew, color=PURPLE, x_range=(0, 50)))
#
#             x = a_value.get_value()
#             x_int = axes_a.coords_to_point(x,0)
#             y = trade_andrew(x)
#             y_int = axes_a.coords_to_point(0,y)
#             y_label = DecimalNumber(num_decimal_places=1).set_color(PURPLE).scale(0.8).next_to(y_int,LEFT,buff=1).set_value(y)
#             p = axes_a.coords_to_point(x,y)
#             dot = Dot(p).set_color(PURPLE)
#             dot.z_index = 2
#             vline = DashedLine(x_int,p).set_color(GREY)
#             hline = DashedLine(y_int,p).set_color(GREY)
#
#             start = axes_a.coords_to_point(0.4,4)
#             end = axes_a.coords_to_point(0.4,y)
#             carrot_line = Line(start=start, end=end, color=PINK, stroke_width=8)
#             #y_label = DecimalNumber(num_decimal_places=1).set_color(PURPLE).scale(0.8).next_to(y_int,RIGHT,buff=0).set_value(y).rotate(np.pi/2)
#
#             start = axes_a.coords_to_point(0,0.4/9)
#             end = axes_a.coords_to_point(x,0.4/9)
#             spinach_line = Line(start=start, end=end, color=PURPLE, stroke_width=8)
#             x_label = DecimalNumber(num_decimal_places=1).set_color(PURPLE).scale(0.8).next_to(x_int,UP,buff=1/4).set_value(x)
#
#             return VGroup(trade_line,dot,vline,hline,y_label,x_label,carrot_line,spinach_line)
#
#         trade_a = always_redraw(Trade_A)
#
#         self.play(FadeIn(trade_m))
#         self.play(m_value.animate.set_value(45-27),run_time=2)
#         self.wait()
#         new_title = Tex('Molly benefits from this exchange rate.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(Transform(title, new_title))
#         self.wait()
#         self.play(m_value.animate.set_value(45),run_time=2)
#         self.wait()
#
#         self.play(FadeIn(trade_a), FadeOut(trade_m))
#         self.wait()
#         self.play(a_value.animate.set_value(9),run_time=2)
#         self.wait()
#         new_title = Tex('Andrew also benefits from this exchange rate.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(Transform(title, new_title))
#         self.wait()
#         self.play(a_value.animate.set_value(0),run_time=2)
#         self.wait()
#
#         """ Trade 2 C for 12 S """
#
#         self.play(FadeIn(trade_m))
#         self.wait()
#         self.play(a_value.animate.set_value(12), m_value.animate.set_value(45-12),run_time=2)
#         self.wait()
#         new_title = Tex('Both benefit.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(Transform(title, new_title))
#         self.wait()
#         self.play(a_value.animate.set_value(0), m_value.animate.set_value(45),run_time=2)
#         self.wait()
#
#         """ Change the exchange rate """
#
#         self.play(FadeOut(title), s_x.animate.set_value(10))
#         self.wait()
#         self.play(a_value.animate.set_value(12), m_value.animate.set_value(45-12),run_time=2)
#         self.wait()
#         title = Tex('Only Andrew benefits.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(FadeIn(title))
#         self.wait()
#         self.play(a_value.animate.set_value(0), m_value.animate.set_value(45),run_time=2)
#         self.wait()
#
#         self.play(FadeOut(title),s_x.animate.set_value(4))
#         self.wait()
#         self.play(a_value.animate.set_value(12), m_value.animate.set_value(45-12),run_time=2)
#         self.wait()
#         title = Tex('Only Molly benefits.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(FadeIn(title))
#         self.wait()
#         self.play(a_value.animate.set_value(0), m_value.animate.set_value(45),run_time=2)
#         self.wait()
#
#         self.play(FadeOut(title), s_x.animate.set_value(6))
#         self.wait()
#         self.play(a_value.animate.set_value(12), m_value.animate.set_value(45-12),run_time=2)
#         self.wait()
#         title = Tex('Both benefit.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(FadeIn(title))
#         self.wait()
#         #self.play(a_value.animate.set_value(0), m_value.animate.set_value(45),run_time=2)
#         #self.wait()
#
#         """ Better than a specific point. """
#
#         m_value.set_value(34)
#         a_value.set_value(11)
#
#         self.play(
#             FadeIn(dotm, dota)
#         )
#
#         """ Unspecialize """
#
#         # in progress
#
#         """ Conclusions """
#
#         new_title = Tex("Exchanging 1C for anything between ", "9S"," and ","4.5S", " works!").set_color(YELLOW).set_color_by_tex_to_color_map({
#                 "9S": BLUE,
#                 "4.5S": RED,
#             }).move_to(title)
#         self.play(Transform(title, new_title))#, self.camera.frame.animate.move_to(final_group).set(width=final_group.width*1.3))
# Out:
# Manim Community v0.18.1
# <video src="PartA_E3/jupyter/animation_5@2024-09-04@09-35-37.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Two-Sided Trade

# %%
# %%manim animation_5
#
# class animation_5(MovingCameraScene):
#
#     def construct(self):
#         """ Make PPFs """
#
#         PPF_axis_small = Axes(
#             x_range=[0, 65, 5],
#             x_length = 7,
#             axis_config={"color": WHITE},
#             x_axis_config={
#                 "numbers_to_include": np.arange(0, 50, 45),
#                 "numbers_with_elongated_ticks": np.arange(0, 50, 10),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":GREEN,
#                 },
#             },
#             y_range=[0, 6, 1],
#             y_length = 6,
#             y_axis_config={
#                 "numbers_to_include": np.arange(0, 6, 5),
#                 "numbers_with_elongated_ticks": np.arange(0, 6, 5),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":ORANGE,
#                 }
#             },
#             tips=False,
#         )
#
#         axes_a = PPF_axis_small.copy()
#         ppf_andrew_graph = axes_a.plot(PPF_Andrew, color=RED, x_range=(0, 18))
#         andrew_name = Tex("Andrew").scale(1.2).next_to(axes_a,UP,buff=1/2).set_color(RED)
#
#         axes_m = PPF_axis_small.copy().next_to(axes_a, LEFT*2)
#         ppf_molly_graph = axes_m.plot(PPF_Molly, color=BLUE, x_range=(0, 45))
#         molly_name = Tex("Molly").scale(1.2).next_to(axes_m,UP,buff=1/2).set_color(BLUE)
#
#         molly_ad = axes_m.coords_to_point(45,0)
#         molly_ad = Dot(molly_ad, radius=0.2, stroke_width=0, fill_opacity=0.3, color='WHITE')
#         molly_ad.z_index = 0
#
#         andrew_ad = axes_a.coords_to_point(0,4)
#         andrew_ad = Dot(andrew_ad, radius=0.2, stroke_width=0, fill_opacity=0.3, color='WHITE')
#         andrew_ad.z_index = 0
#
#         p1m = axes_m.coords_to_point(45, 0)
#         p1a = axes_a.coords_to_point(0, 4)
#         dotm = Dot(p1m)
#         dotm.z_index = 2
#         dota = Dot(p1a)
#         dota.z_index = 2
#
#         frame_group = VGroup(
#             axes_m, dotm, molly_name, ppf_molly_graph, molly_ad,
#             axes_a, dota, andrew_name, ppf_andrew_graph, andrew_ad,
#         )
#         title = Tex('But is a guild necessary?').scale(1.3).set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#
#         self.add(frame_group, title)
#         self.camera.frame.move_to(frame_group).set(width=frame_group.width*1.3),
#
#         self.wait()
#
#         """ Self Trade """
#
#         m_value = ValueTracker(45)
#         a_value = ValueTracker(0)
#
#         def Move_M():
#             x = m_value.get_value()
#             x_int = axes_m.coords_to_point(x,0)
#             x_label = DecimalNumber(num_decimal_places=2).set_color(GREEN).scale(0.8).next_to(x_int,DOWN,buff=2/3).set_value(x)
#             y = PPF_Molly(x)
#             y_int = axes_m.coords_to_point(0,y)
#             y_label = DecimalNumber(num_decimal_places=2).set_color(ORANGE).scale(0.8).next_to(y_int,LEFT).set_value(y)
#             p = axes_m.coords_to_point(x,y)
#             dot = Dot(p).set_color(WHITE)
#             dot.z_index = 2
#             vline = DashedLine(x_int,p).set_color(GREY)
#             hline = DashedLine(y_int,p).set_color(GREY)
#
#             return VGroup(dot,vline,hline,x_label,y_label)
#
#         def Move_A():
#             x = a_value.get_value()
#             x_int = axes_a.coords_to_point(x,0)
#             x_label = DecimalNumber(num_decimal_places=2).set_color(GREEN).scale(0.8).next_to(x_int,DOWN,buff=2/3).set_value(x)
#             y = PPF_Andrew(x)
#             y_int = axes_a.coords_to_point(0,y)
#             y_label = DecimalNumber(num_decimal_places=2).set_color(ORANGE).scale(0.8).next_to(y_int,LEFT).set_value(y)
#             p = axes_a.coords_to_point(x,y)
#             dot = Dot(p).set_color(WHITE)
#             dot.z_index = 2
#             vline = DashedLine(x_int,p).set_color(GREY)
#             hline = DashedLine(y_int,p).set_color(GREY)
#
#             return VGroup(dot,vline,hline,x_label,y_label)
#
#         self.remove(dotm)
#         dotm = always_redraw(Move_M)
#         self.add(dotm)
#
#         self.play(m_value.animate.set_value(36),run_time=3)
#         self.wait()
#
#         molly_cost = Tex("1C"," for ","9S").set_color(BLUE).next_to(molly_name,DOWN)
#         self.play(FadeIn(molly_cost))
#         self.wait()
#
#         m_box = SurroundingRectangle(molly_cost[2], buff=1/4)
#         m_sign = Tex("-").scale(1.5).next_to(m_box, DOWN).set_color(YELLOW)
#         self.play(FadeIn(m_box), FadeIn(m_sign))
#         self.wait()
#
#         self.play(m_value.animate.set_value(45),run_time=3)
#         new_title = Tex('Molly benefits if she trades away less than 9S.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(Transform(title, new_title))
#         self.wait()
#
#         self.remove(dota)
#         dota = always_redraw(Move_A)
#         self.add(dota)
#
#         self.play(a_value.animate.set_value(9/2),run_time=3)
#         self.wait()
#
#         andrew_cost = Tex("1C"," for ","4.5S").set_color(RED).next_to(andrew_name,DOWN)
#         self.play(FadeIn(andrew_cost))
#         self.wait()
#
#         a_box = SurroundingRectangle(andrew_cost[2], buff=1/4)
#         a_sign = Tex("+").scale(1.5).next_to(a_box, DOWN).set_color(YELLOW)
#         self.play(FadeIn(a_box), FadeIn(a_sign))
#         self.wait()
#
#         new_title = Tex('Andrew benefits if he trades for more than 4.5S.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(Transform(title, new_title))
#         self.wait()
#
#         self.play(a_value.animate.set_value(0),run_time=3)
#         self.wait()
#
#         """ Exchange Rate """
#
#         c_x = ValueTracker(1)
#         s_x = ValueTracker(6)
#         def Exchange():
#             c = c_x.get_value()
#             c_value = DecimalNumber(num_decimal_places=0).set_value(c)
#             s = s_x.get_value()
#             s_value = DecimalNumber(num_decimal_places=1).set_value(s)
#
#             return Tex(f"{int(c)} C"," for ",f"{round(s,1)} S").set_color(PINK).scale(1.2).next_to(frame_group,UP, buff=-1/4)
#         exchange = always_redraw(Exchange)
#         self.play(FadeIn(exchange))
#         self.wait()
#
#         e_box = SurroundingRectangle(exchange[2], buff=1/4)
#         self.play(FadeIn(e_box))
#         self.wait()
#
#         alpha_m = 0
#         alpha_a = 1
#
#         def trade_molly(s):
#             x = s - (1-alpha_m)*45
#             return alpha_m*5 - x*c_x.get_value()/s_x.get_value()
#
#         def Trade_M():
#             trade_line = DashedVMobject(axes_m.plot(trade_molly, color=PINK, x_range=(0, 50)))
#
#             x = m_value.get_value()
#             x_int = axes_m.coords_to_point(x,0)
#             y = trade_molly(x)
#             y_int = axes_m.coords_to_point(0,y)
#             y_label = DecimalNumber(num_decimal_places=2).set_color(ORANGE).scale(0.8).next_to(y_int,LEFT,buff=1).set_value(y)
#             p = axes_m.coords_to_point(x,y)
#             dot = Dot(p).set_color(WHITE)
#             dot.z_index = 2
#             vline = DashedLine(x_int,p).set_color(GREY)
#             hline = DashedLine(y_int,p).set_color(GREY)
#
#             return VGroup(trade_line,dot,vline,hline,y_label)
#
#         trade_m = always_redraw(Trade_M)
#
#
#         def trade_andrew(s):
#             x = s - (1-alpha_a)*18
#             return alpha_a*4 - x*c_x.get_value()/s_x.get_value()
#
#         def Trade_A():
#             trade_line = DashedVMobject(axes_a.plot(trade_andrew, color=PINK, x_range=(0, 50)))
#
#             x = a_value.get_value()
#             x_int = axes_a.coords_to_point(x,0)
#             y = trade_andrew(x)
#             y_int = axes_a.coords_to_point(0,y)
#             y_label = DecimalNumber(num_decimal_places=2).set_color(ORANGE).scale(0.8).next_to(y_int,LEFT,buff=1).set_value(y)
#             p = axes_a.coords_to_point(x,y)
#             dot = Dot(p).set_color(WHITE)
#             dot.z_index = 2
#             vline = DashedLine(x_int,p).set_color(GREY)
#             hline = DashedLine(y_int,p).set_color(GREY)
#
#             return VGroup(trade_line,dot,vline,hline,y_label)
#
#         trade_a = always_redraw(Trade_A)
#
#         self.play(FadeIn(trade_m))
#         self.play(m_value.animate.set_value(45-27),run_time=2)
#         self.wait()
#         new_title = Tex('Molly benefits from this exchange rate.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(Transform(title, new_title))
#         self.wait()
#         self.play(m_value.animate.set_value(45),run_time=2)
#         self.wait()
#
#         self.play(FadeIn(trade_a), FadeOut(trade_m))
#         self.wait()
#         self.play(a_value.animate.set_value(9),run_time=2)
#         self.wait()
#         new_title = Tex('Andrew also benefits from this exchange rate.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(Transform(title, new_title))
#         self.wait()
#         self.play(a_value.animate.set_value(0),run_time=2)
#         self.wait()
#
#         """ Trade 2 C for 12 S """
#
#         self.play(FadeIn(trade_m))
#         self.wait()
#         self.play(a_value.animate.set_value(12), m_value.animate.set_value(45-12),run_time=2)
#         self.wait()
#         new_title = Tex('Both benefit.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(Transform(title, new_title))
#         self.wait()
#         self.play(a_value.animate.set_value(0), m_value.animate.set_value(45),run_time=2)
#         self.wait()
#
#         """ Change the exchange rate """
#
#         self.play(s_x.animate.set_value(10))
#         self.wait()
#         self.play(a_value.animate.set_value(12), m_value.animate.set_value(45-12),run_time=2)
#         self.wait()
#         new_title = Tex('Only Andrew benefits.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(Transform(title, new_title))
#         self.wait()
#         self.play(a_value.animate.set_value(0), m_value.animate.set_value(45),run_time=2)
#         self.wait()
#
#         self.play(s_x.animate.set_value(4))
#         self.wait()
#         self.play(a_value.animate.set_value(12), m_value.animate.set_value(45-12),run_time=2)
#         self.wait()
#         new_title = Tex('Only Molly benefits.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(Transform(title, new_title))
#         self.wait()
#         self.play(a_value.animate.set_value(0), m_value.animate.set_value(45),run_time=2)
#         self.wait()
#
#         self.play(s_x.animate.set_value(6))
#         self.wait()
#         self.play(a_value.animate.set_value(12), m_value.animate.set_value(45-12),run_time=2)
#         self.wait()
#         new_title = Tex('Both benefit.').set_color(YELLOW).next_to(frame_group, UP, buff=1/2)
#         self.play(Transform(title, new_title))
#         self.wait()
#         self.play(a_value.animate.set_value(0), m_value.animate.set_value(45),run_time=2)
#         self.wait()
#
#         """ Unspecialize """
#
#         # in progress
#
#         """ Conclusions """
#
#         new_title = Tex("Exchanging 1C for anything between ", "9S"," and ","4.5S", " works!").set_color(YELLOW).set_color_by_tex_to_color_map({
#                 "9S": BLUE,
#                 "4.5S": RED,
#             }).move_to(title)
#         self.play(Transform(title, new_title))#, self.camera.frame.animate.move_to(final_group).set(width=final_group.width*1.3))

# %% [markdown]
# ## Animation 5 | Trade With Another (unused)

# %%
# %%manim animation_old
#
# class animation_old(Scene):
#
#     def construct(self):
#
#         """ Definitions """
#
#         PPF_axis = Axes(
#             x_range=[0, 65, 5],
#             x_length = 7,
#             axis_config={"color": WHITE},
#             x_axis_config={
#                 "numbers_to_include": np.arange(0, 65, 15),
#                 "numbers_with_elongated_ticks": np.arange(0, 65, 10),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":GREEN,
#                 },
#             },
#             y_range=[0, 10, 1],
#             y_length = 6,
#             y_axis_config={
#                 "numbers_to_include": np.arange(0, 11, 2),
#                 "numbers_with_elongated_ticks": np.arange(0, 11, 5),
#                 "decimal_number_config": {
#                     "num_decimal_places":0,
#                     "color":ORANGE,
#                 }
#             },
#             tips=False,
#         )
#
#         alpha_m = 2/3
#         alpha_a = 1/3
#
#         """ Starting Objects """
#
#         axes = PPF_axis.shift(RIGHT*2).scale(0.8)
#
#         ppf_molly_graph = axes.plot(PPF_Molly, color=BLUE, x_range=(0, 45))
#         molly = Rectangle(height=3, width=3, color=BLUE).move_to(LEFT*4.5 + UP*2)
#         molly.z_index = 2
#         molly_name = Tex("Molly").scale(1.5).next_to(molly,LEFT,buff=-1/2).set_color(BLUE).rotate(np.pi/2)
#         molly_cost = Tex("$1C=9S$").next_to(molly,RIGHT,buff=-0.6).set_color(BLUE).rotate(np.pi/2)
#         molly_group = VGroup(molly,molly_name,molly_cost)
#
#         m_carrots = Rectangle(height=alpha_m*3, width=3, color=ORANGE, fill_opacity=1)
#         m_spinach = Rectangle(height=(1-alpha_m)*3, width=3, color=GREEN, fill_opacity=1)
#         molly_crops = VGroup(m_carrots,m_spinach.next_to(m_carrots,DOWN,buff=0)).move_to(molly)
#
#         ppf_andrew_graph = axes.plot(PPF_Andrew, color=RED, x_range=(0, 18))
#         andrew = Rectangle(height=3, width=3, color=RED).move_to(LEFT*4.5 + DOWN*2)
#         andrew.z_index = 2
#         andrew_name = Tex("Andrew").scale(1.5).next_to(andrew,LEFT,buff=-0.8).set_color(RED).rotate(np.pi/2)
#         andrew_cost = Tex("$1C=4.5S$").next_to(andrew,RIGHT,buff=-0.8).set_color(RED).rotate(np.pi/2)
#         andrew_group = VGroup(andrew,andrew_name,andrew_cost)
#
#         a_carrots = Rectangle(height=alpha_a*3, width=3, color=ORANGE, fill_opacity=1)
#         a_spinach = Rectangle(height=(1-alpha_a)*3, width=3, color=GREEN, fill_opacity=1)
#         andrew_crops = VGroup(a_carrots,a_spinach.next_to(a_carrots,DOWN,buff=0)).move_to(andrew)
#
#         p1m = axes.coords_to_point((1-alpha_m)*45, alpha_m*5)
#         p1a = axes.coords_to_point((1-alpha_a)*18, alpha_a*4)
#         dotm = Dot(p1m)
#         dota = Dot(p1a)
#
#         """ Setup """
#
#         self.add(axes,molly_group,molly_crops,andrew_group,andrew_crops,ppf_molly_graph,ppf_andrew_graph,dotm,dota)
#         self.wait(1/2)
#
#         """ Introduce The Exchange Rate """
#
#         c_x,s_x = 1,20
#         exchange = Tex(str(c_x)+' {{C}} for '+str(s_x)+' {{S}}').move_to(UP*2+RIGHT*3).scale(1.5).set_color_by_tex_to_color_map({
#                 "C": ORANGE,
#                 "S": GREEN,
#             })
#
#         def trade_molly(s):
#             x = s - (1-alpha_m)*45
#             return alpha_m*5 - x*c_x/s_x
#         trade_molly_graph = DashedVMobject(axes.plot(trade_molly, color=PINK, x_range=(0, 50)))
#
#         def trade_andrew(s):
#             x = s - (1-alpha_a)*18
#             return alpha_a*4 - x*c_x/s_x
#         trade_andrew_graph = DashedVMobject(axes.plot(trade_andrew, color=PINK, x_range=(0, 50)))
#
#         self.play(FadeIn(exchange))
#         self.wait(1/2)
#         framebox1 = SurroundingRectangle(exchange, buff = 0.3).set_color(PINK)
#         self.play(Create(framebox1))
#         self.wait(1/2)
#         self.play(dota.animate.set_opacity(0.1),ppf_andrew_graph.animate.set_opacity(0.1))
#         self.wait(1/2)
#         self.play(Create(trade_molly_graph))
#         self.wait(1/2)
#
#         c_x,s_x = 1,30
#         def trade_molly(s):
#             x = s - (1-alpha_m)*45
#             return alpha_m*5 - x*c_x/s_x
#         trade_molly_graph_new = DashedVMobject(axes.plot(trade_molly, color=PINK, x_range=(0, 50)))
#         exchange_new = Tex(str(c_x)+' {{C}} for '+str(s_x)+' {{S}}').move_to(UP*2+RIGHT*3).scale(1.5).set_color_by_tex_to_color_map({
#                 "C": ORANGE,
#                 "S": GREEN,
#             })
#         self.play(Transform(trade_molly_graph,trade_molly_graph_new),Transform(exchange,exchange_new))
#
#         c_x,s_x = 1,2
#         def trade_molly(s):
#             x = s - (1-alpha_m)*45
#             return alpha_m*5 - x*c_x/s_x
#         trade_molly_graph_new = DashedVMobject(axes.plot(trade_molly, color=PINK, x_range=(0, 50)))
#         exchange_new = Tex(str(c_x)+' {{C}} for '+str(s_x)+' {{S}}').move_to(UP*2+RIGHT*3).scale(1.5).set_color_by_tex_to_color_map({
#                 "C": ORANGE,
#                 "S": GREEN,
#             })
#         self.play(Transform(trade_molly_graph,trade_molly_graph_new),Transform(exchange,exchange_new))
#
#         b = axes.coords_to_point(45, 0)
#         c = axes.coords_to_point(50, trade_molly(50))
#         if c_x/s_x > 1/9:
#             b = axes.coords_to_point(0, 5)
#             c = axes.coords_to_point(0, trade_molly(0))
#         trade_region_molly = Polygon(p1m,b,c, color=BLUE,fill_opacity=0)
#         #self.play(Create(trade_region_molly))
#         self.play(trade_region_molly.animate.set_fill(BLUE, opacity=0.5))
#         self.wait(1/2)
#
#         for c_x,s_x in [[1,80]]: #something's not right with andrew's area when s_x is less than 4.5...
#             def trade_molly(s):
#                 x = s - (1-alpha_m)*45
#                 return alpha_m*5 - x*c_x/s_x
#             def trade_molly_inv(c):
#                 return alpha_m*5*(s_x/c_x) - c*(s_x/c_x) + (1-alpha_m)*45
#             trade_molly_graph_new = DashedVMobject(axes.plot(trade_molly, color=PINK, x_range=(0, 50)))
#             exchange_new = Tex(str(c_x)+' {{C}} for '+str(s_x)+' {{S}}').move_to(UP*2+RIGHT*3).scale(1.5).set_color_by_tex_to_color_map({
#                     "C": ORANGE,
#                     "S": GREEN,})
#             self.play(Transform(trade_molly_graph,trade_molly_graph_new),Transform(exchange,exchange_new),FadeOut(trade_region_molly))
#             b = axes.coords_to_point(45, 0)
#             c = axes.coords_to_point(trade_molly_inv(0),0)
#             if c_x/s_x > 1/9:
#                 b = axes.coords_to_point(0, 5)
#                 c = axes.coords_to_point(0, trade_molly(0))
#             trade_region_molly = Polygon(p1m,b,c, color=BLUE,fill_opacity=0).set_fill(BLUE, opacity=0.5)
#             self.play(FadeIn(trade_region_molly))
#             self.wait(1/2)
#
#             self.play(dota.animate.set_opacity(1),ppf_andrew_graph.animate.set_opacity(1))
#
#             def trade_andrew(s):
#                 x = s - (1-alpha_a)*18
#                 return alpha_a*4 - x*c_x/s_x
#             def trade_andrew_inv(c):
#                 return alpha_a*4*(s_x/c_x) - c*(s_x/c_x) + (1-alpha_a)*18
#             trade_andrew_graph = DashedVMobject(axes.plot(trade_andrew, color=PINK, x_range=(0, 50)))
#
#             self.play(Create(trade_andrew_graph))
#             b = axes.coords_to_point(0, 4)
#             c = axes.coords_to_point(0,0)
#             if c_x/s_x < 1/4.5:
#                 b = axes.coords_to_point(18, 0)
#                 c = axes.coords_to_point(trade_andrew_inv(0), 0)
#             trade_region_andrew = Polygon(p1a,b,c, color=RED,fill_opacity=0).set_fill(RED, opacity=0.5)
#             self.play(FadeIn(trade_region_andrew))
#
#             arrow_molly = Arrow(np.array([0, 0, 0]), np.array([2, -1/2, 0]), color=BLUE, buff=0).next_to(dotm,DOWN+RIGHT,buff=0)
#             arrow_andrew = Arrow(np.array([0, 0, 0]), np.array([2, -1/2, 0]), color=RED, buff=0).next_to(dota,DOWN+RIGHT,buff=0)
#
#             self.play(FadeIn(arrow_molly),FadeIn(arrow_andrew))
#             self.play(FadeOut(arrow_molly),FadeOut(arrow_andrew))
#
#
#         c_x,s_x = 1,80
#         alpha_m = 0
#         alpha_a = 1
#
#         m_carrots_new = Rectangle(height=alpha_m*3, width=3, color=ORANGE, fill_opacity=1)
#         m_spinach_new = Rectangle(height=(1-alpha_m)*3, width=3, color=GREEN, fill_opacity=1)
#         molly_crops_new = VGroup(m_carrots_new,m_spinach_new.next_to(m_carrots_new,DOWN,buff=0)).move_to(molly)
#
#         a_carrots_new = Rectangle(height=alpha_a*3, width=3, color=ORANGE, fill_opacity=1)
#         a_spinach_new = Rectangle(height=(1-alpha_a)*3, width=3, color=GREEN, fill_opacity=1)
#         andrew_crops_new = VGroup(a_carrots_new,a_spinach_new.next_to(a_carrots_new,DOWN,buff=0)).move_to(andrew)
#
#         p1m = axes.coords_to_point((1-alpha_m)*45, alpha_m*5)
#         p1a = axes.coords_to_point((1-alpha_a)*18, alpha_a*4)
#         dotm_new = Dot(p1m)
#         dota_new = Dot(p1a)
#
#         def trade_molly(s):
#             x = s - (1-alpha_m)*45
#             return alpha_m*5 - x*c_x/s_x
#         def trade_molly_inv(c):
#             return alpha_m*5*(s_x/c_x) - c*(s_x/c_x) + (1-alpha_m)*45
#         trade_molly_graph_new = DashedVMobject(axes.plot(trade_molly, color=PINK, x_range=(0, 50)))
#         exchange_new = Tex(str(c_x)+' {{C}} for '+str(s_x)+' {{S}}').move_to(UP*2+RIGHT*3).scale(1.5).set_color_by_tex_to_color_map({
#                 "C": ORANGE,
#                 "S": GREEN,})
#         def trade_andrew(s):
#             x = s - (1-alpha_a)*18
#             return alpha_a*4 - x*c_x/s_x
#         def trade_andrew_inv(c):
#             return alpha_a*4*(s_x/c_x) - c*(s_x/c_x) + (1-alpha_a)*18
#         trade_andrew_graph_new = DashedVMobject(axes.plot(trade_andrew, color=PINK, x_range=(0, 50)))
#         self.play(Transform(trade_molly_graph,trade_molly_graph_new),Transform(trade_andrew_graph,trade_andrew_graph_new),
#                   Transform(dotm,dotm_new),Transform(dota,dota_new),
#                   Transform(exchange,exchange_new),
#                   FadeOut(trade_region_molly),FadeOut(trade_region_andrew),
#                   Transform(molly_crops,molly_crops_new),Transform(andrew_crops,andrew_crops_new))
#
#         b = axes.coords_to_point(45, 0)
#         c = axes.coords_to_point(trade_molly_inv(0),0)
#         if c_x/s_x > 1/9:
#             b = axes.coords_to_point(0, 5)
#             c = axes.coords_to_point(0, trade_molly(0))
#         trade_region_molly = Polygon(p1m,b,c, color=BLUE,fill_opacity=0).set_fill(BLUE, opacity=0.5)
#
#         b = axes.coords_to_point(0, 4)
#         c = axes.coords_to_point(0,0)
#         if c_x/s_x < 1/4.5:
#             b = axes.coords_to_point(18, 0)
#             c = axes.coords_to_point(trade_andrew_inv(0), 0)
#         trade_region_andrew = Polygon(p1a,b,c, color=RED,fill_opacity=0).set_fill(RED, opacity=0.5)
#
#         self.play(FadeIn(trade_region_molly),FadeIn(trade_region_andrew))
#         self.wait()
#
#
#         alpha_m = 0
#         alpha_a = 1
#         for pair in [[1,6],[1,4.55],[1,9],[1,6]]:
#             c_x,s_x = pair[0],pair[1]
#
#             def trade_molly(s):
#                 x = s - (1-alpha_m)*45
#                 return alpha_m*5 - x*c_x/s_x
#             def trade_molly_inv(c):
#                 return alpha_m*5*(s_x/c_x) - c*(s_x/c_x) + (1-alpha_m)*45
#             trade_molly_graph_new = DashedVMobject(axes.plot(trade_molly, color=PINK, x_range=(0, 50)))
#             exchange_new = Tex(str(c_x)+' {{C}} for '+str(s_x)+' {{S}}').move_to(UP*2+RIGHT*3).scale(1.5).set_color_by_tex_to_color_map({
#                     "C": ORANGE,
#                     "S": GREEN,})
#             def trade_andrew(s):
#                 x = s - (1-alpha_a)*18
#                 return alpha_a*4 - x*c_x/s_x
#             def trade_andrew_inv(c):
#                 return alpha_a*4*(s_x/c_x) - c*(s_x/c_x) + (1-alpha_a)*18
#             trade_andrew_graph_new = DashedVMobject(axes.plot(trade_andrew, color=PINK, x_range=(0, 50)))
#             self.play(Transform(trade_molly_graph,trade_molly_graph_new),Transform(trade_andrew_graph,trade_andrew_graph_new),
#                       Transform(exchange,exchange_new),
#                       FadeOut(trade_region_molly),FadeOut(trade_region_andrew))
#
#             b = axes.coords_to_point(45, 0)
#             c = axes.coords_to_point(trade_molly_inv(0),0)
#             if c_x/s_x > 1/9:
#                 b = axes.coords_to_point(0, 5)
#                 c = axes.coords_to_point(0, trade_molly(0))
#             trade_region_molly = Polygon(p1m,b,c, color=BLUE,fill_opacity=0).set_fill(BLUE, opacity=0.5)
#
#             b = axes.coords_to_point(0, 4)
#             c = axes.coords_to_point(0,0)
#             if c_x/s_x < 1/4.5:
#                 b = axes.coords_to_point(18, 0)
#                 c = axes.coords_to_point(trade_andrew_inv(0), 0)
#             trade_region_andrew = Polygon(p1a,b,c, color=RED,fill_opacity=0).set_fill(RED, opacity=0.5)
#
#             self.play(FadeIn(trade_region_molly),FadeIn(trade_region_andrew))
#             self.wait()
#
#         c_x,s_x = 1,6
#         dotm_trade = Dot(color=PINK).move_to(dotm)
#         dota_trade = Dot(color=PINK).move_to(dota)
#         for i in [1,2,3,4,3,2]:
#             p1m = axes.coords_to_point((1-alpha_m)*45 - s_x/c_x*i, alpha_m*5 + i)
#             p1a = axes.coords_to_point((1-alpha_a)*18 + s_x/c_x*i, alpha_a*4 - i)
#             self.play(dotm_trade.animate.move_to(p1m),dota_trade.animate.move_to(p1a),)
#         self.wait()
#
#         alpha_m = 1/3.5
#         alpha_a = 2/5
#         p1m = axes.coords_to_point((1-alpha_m)*45, alpha_m*5)
#         p1a = axes.coords_to_point((1-alpha_a)*18, alpha_a*4)
#         dotm = Dot(p1m)
#         dota = Dot(p1a)
#         self.play(FadeIn(dotm),FadeIn(dota))
#         self.wait()
# Out:
# Manim Community v0.18.1
# <video src="PartA_E3/jupyter/animation_old@2024-09-02@14-01-46.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### Merge and Convert Videos

# %%
video_path = config.media_dir+'/videos/ANIMATIONS/1080p10/'

Make_MOV(video_path)
# Out:
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x124811800] Auto-inserting h264_mp4toannexb bitstream filter
# Input #0, concat, from 'concat.txt':
#   Duration: N/A, start: 0.000000, bitrate: 672 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 672 kb/s, 10.12 fps, 10 tbr, 10240 tbn, 20 tbc
#     Metadata:
#       handler_name    : VideoHandler
# Output #0, mp4, to 'PartA_E3/videos/ANIMATIONS/1080p10/./media.mp4':
#   Metadata:
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, q=2-31, 672 kb/s, 10.12 fps, 10 tbr, 10240 tbn, 10240 tbc
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x124811800] Auto-inserting h264_mp4toannexb bitstream filter
#     Last message repeated 3 times
# frame= 1916 fps=0.0 q=-1.0 Lsize=   10658kB time=00:03:11.30 bitrate= 456.4kbits/s speed=7.29e+03x
# video:10634kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.231809%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'PartA_E3/videos/ANIMATIONS/1080p10/animation_2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     comment         : Rendered with Manim Community v0.18.1
#   Duration: 00:00:38.50, start: 0.000000, bitrate: 632 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 630 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x150058000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mov, to 'PartA_E3/videos/ANIMATIONS/1080p10/animation_2_convert.mov':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.18.1
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mjpeg (jpeg / 0x6765706A), yuvj420p(pc), 2160x1080, q=2-31, 200 kb/s, 10 fps, 10240 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  385 fps=0.0 q=2.0 Lsize=   51036kB time=00:00:38.40 bitrate=10887.6kbits/s speed=40.9x
# video:51033kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005014%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'PartA_E3/videos/ANIMATIONS/1080p10/media.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 00:03:11.60, start: 0.000000, bitrate: 455 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 455 kb/s, 10.01 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x118708000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mov, to 'PartA_E3/videos/ANIMATIONS/1080p10/media_convert.mov':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mjpeg (jpeg / 0x6765706A), yuvj420p(pc), 2160x1080, q=2-31, 200 kb/s, 10 fps, 10240 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame= 1916 fps=415 q=2.0 Lsize=  200131kB time=00:03:11.50 bitrate=8561.2kbits/s speed=41.4x
# video:200121kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004758%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'PartA_E3/videos/ANIMATIONS/1080p10/animation_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     comment         : Rendered with Manim Community v0.18.1
#   Duration: 00:00:17.10, start: 0.000000, bitrate: 666 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 672 kb/s, 10.12 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x148050000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mov, to 'PartA_E3/videos/ANIMATIONS/1080p10/animation_0_convert.mov':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.18.1
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mjpeg (jpeg / 0x6765706A), yuvj420p(pc), 2160x1080, q=2-31, 200 kb/s, 10 fps, 10240 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  171 fps=0.0 q=2.0 Lsize=   14324kB time=00:00:17.00 bitrate=6902.7kbits/s speed=37.4x
# video:14323kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.010991%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'PartA_E3/videos/ANIMATIONS/1080p10/animation_1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     comment         : Rendered with Manim Community v0.18.1
#   Duration: 00:00:03.00, start: 0.000000, bitrate: 94 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 91 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x128e20000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mov, to 'PartA_E3/videos/ANIMATIONS/1080p10/animation_1_convert.mov':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.18.1
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mjpeg (jpeg / 0x6765706A), yuvj420p(pc), 2160x1080, q=2-31, 200 kb/s, 10 fps, 10240 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=   30 fps=0.0 q=2.0 Lsize=     760kB time=00:00:02.90 bitrate=2146.1kbits/s speed=36.3x
# video:759kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.121486%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'PartA_E3/videos/ANIMATIONS/1080p10/animation_5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     comment         : Rendered with Manim Community v0.18.1
#   Duration: 00:01:30.00, start: 0.000000, bitrate: 350 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 349 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x120078000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mov, to 'PartA_E3/videos/ANIMATIONS/1080p10/animation_5_convert.mov':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.18.1
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mjpeg (jpeg / 0x6765706A), yuvj420p(pc), 2160x1080, q=2-31, 200 kb/s, 10 fps, 10240 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  900 fps=401 q=2.0 Lsize=   88796kB time=00:01:29.90 bitrate=8091.4kbits/s speed=40.1x
# video:88791kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005556%
# ffmpeg version 4.3.2 Copyright (c) 2000-2021 the FFmpeg developers
#   built with clang version 12.0.1
#   configuration: --prefix=/opt/anaconda3 --cc=arm64-apple-darwin20.0.0-clang --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libmp3lame --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/pkg-config --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1645955491330/_build_env/bin/x86_64-apple-darwin13.4.0-clang
#   libavutil      56. 51.100 / 56. 51.100
#   libavcodec     58. 91.100 / 58. 91.100
#   libavformat    58. 45.100 / 58. 45.100
#   libavdevice    58. 10.100 / 58. 10.100
#   libavfilter     7. 85.100 /  7. 85.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  7.100 /  5.  7.100
#   libswresample   3.  7.100 /  3.  7.100
#   libpostproc    55.  7.100 / 55.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'PartA_E3/videos/ANIMATIONS/1080p10/animation_4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#     comment         : Rendered with Manim Community v0.18.1
#   Duration: 00:00:43.00, start: 0.000000, bitrate: 460 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2160x1080, 459 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x1293c0000] deprecated pixel format used, make sure you did set range correctly
# Output #0, mov, to 'PartA_E3/videos/ANIMATIONS/1080p10/animation_4_convert.mov':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     comment         : Rendered with Manim Community v0.18.1
#     encoder         : Lavf58.45.100
#     Stream #0:0(und): Video: mjpeg (jpeg / 0x6765706A), yuvj420p(pc), 2160x1080, q=2-31, 200 kb/s, 10 fps, 10240 tbn, 10 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.91.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: N/A
# frame=  430 fps=376 q=2.0 Lsize=   45218kB time=00:00:42.90 bitrate=8634.6kbits/s speed=37.6x
# video:45215kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006203%
# rm: PartA_E3/videos/ANIMATIONS/1080p10/./media.mov: No such file or directory
