# %%
from Lectures import *
# %matplotlib inline
warnings.filterwarnings('ignore')

file_name = 'timeline'
title = '\\textbf{Intro Micro | Week 14}'
subtitle = ''
author = ''#'Taylor J. Weidman'

export_the_file([file_name, title, subtitle, author])
# Out:
# [NbConvertApp] Converting notebook file_to_convert.ipynb to pdf
# [NbConvertApp] Writing 21294 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 15989 bytes to timeline_week12.pdf

# %% [markdown]
# # Week 14 | Labor Market

# %% [markdown]
# ## Introduction to the Week
#
# Hi economists,
#
# This is a short week before we head off to the break! It's hard to imagine we only have three more classes this semester.
#
# Tuesday we're doing two things. The big thing we'll do is build the last model in this class (what!, no way), which allows us a more satisfying pin down where to live on the PPF we built in Part A. We'll do this by building the budget for buyer. We'll use the linkages between the final goods market and the labor market to develop a more sophisticated model of the minimum wage in a setting when there are few buyers of labor: Monopsony! This will allow us to pin down where buyers' income comes from, making the budget for the Consumer's Problem.
#
# Come to class having skimmed Chapters 18 and 21.
#
# Thursday I want for no one to do any economics and for everyone to get a few extra hours of sleep.
#
# Love always,
#
# Taylor
#
# ## Tutorials
#
# ## Other Resources

# %% [markdown]
# ## Class 1 |

# %% [markdown]
# ## Class 2 |

# %% [markdown]
# # Last Class
#
# So what have we done?
#
# The big questions we've aimed at are twofold:
# 1. What is possible for us to achieve?
# 2. And how to we distribute what we've achieved?
#
# To do this we started by introducing the basic problem:
