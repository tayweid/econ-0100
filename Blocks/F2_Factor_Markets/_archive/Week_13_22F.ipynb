# %%
from lectures import *
# %matplotlib inline
warnings.filterwarnings('ignore')

file_name = 'timeline'
title = '\\textbf{Intro Micro | Week 13}'
subtitle = ''
author = ''#'Taylor J. Weidman'

export_the_file([file_name, title, subtitle, author])
# Out:
# [NbConvertApp] Converting notebook file_to_convert.ipynb to pdf
# [NbConvertApp] Writing 21294 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 15989 bytes to timeline_week12.pdf

# %% [markdown]
# # Week 13 | Factor Markets

# %% [markdown]
# ## Introduction to the Week
#
# Hi everyone!
#
# I hope last week was lovely for you. This week we're back to our regularly scheduled program and we have a lot of fun synthesis work in store.
#
# Tuesday we're bringing together our market structures, doing a head to head with each one, examining the differences and similarities. And Thursday after MiniExam E we're going to make our last turn of attention to Buyers!
#
# Finally, I'm giving an blanket extension to turn in Homework E on Thursday if you're feeling under-prepared with the work. Homework E Demo is posted and we're going to do some helpful work in class tomorrow.
#
# I'm looking forward to seeing everyone in class tomorrow. Love always.
#
# Taylor
#
# ## Reading
#
# - Chapter 18. Factor Markets
# - Chapter 21. Consumer Theory
